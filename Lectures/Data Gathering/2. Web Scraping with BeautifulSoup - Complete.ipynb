# %% [markdown]
# # Web Scraping with `BeautifulSoup`
#
# Sometimes you won't be able to find a neat data set for your project. However, if the data you want exists on the internet there is a chance that you can scrape the data yourself. Let's learn how to do that in python.
#
# ## What We'll Accomplish in this Notebook
#
# In this notebook we'll do the following:
# - Learn about the structure of an html page,
# - Introduce the `BeautifulSoup` package,
# - Parse html code with a toy example,
# - Scrape data from some saved html code,
# - Download then scrape an actual webpage.
#
# Let's get going!

# %%
## Import base packages we'll use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from seaborn import set_style
set_style("whitegrid")

# %% [markdown]
# ## Scraping Data with `BeautifulSoup`
#
# ### Importing `BeautifulSoup`
#
# In order to use `BeautifulSoup` to scrape web data we first need to make sure that we have it installed on our computer. Try to run the following code:

# %%
## this import BeautifulSoup
from bs4 import BeautifulSoup

# %% [markdown]
# If the above code does not work you'll need to install the package before being able to run the code in this notebook. Here are installation instructions from the `BeautifulSoup` documentation, <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-beautiful-soup">https://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-beautiful-soup</a>.

# %% [markdown]
# ### The Structure of an HTML Page
#
# `BeautifulSoup` takes in an HTML document and will 'parse' it for you so that you can extract the information you want. To best understand what that means let's look at a toy example of a webpage. To see what the snippet of html code below looks like in a web browser click here <a href="SampleHTML.html">SampleHTML.html</a>.

# %%
## This is an html chunk
## It has a head and a body, just like you
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
</body>
</html>
"""

# %% [markdown]
# We can now use `BeautifulSoup` to parse this simple html chunk.

# %%
## Now we make a BeautifulSoup object out of the html code
## The first input is the html code
## The second input is how you want BeautifulSoup
## to parse the code
soup = BeautifulSoup(html_doc,'html.parser')

# %%
## Let's use the prettify method to make our html pretty and see what it has to say
## Ideally this is how someone writing pure html code would write their code
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# Html files have a natural tree structure that we'll briefly cover now. Here's the tree of our sample html:
#
# <img src = "html_tree.png" width = "50%"></img>
#
# Each level in the tree represents a 'generation' of the html code. for instance the body has 3 p children, the leftmost p has one b child. `BeautifulSoup` helps us traverse these trees to gather the data we want.
#
# We'll now traverse this html sapling.

# %%
## Below are some examples of beautifulsoup methods and 
## attributes that help us better understand the structure 
## of html code

# %%
## We can traverse to the "title" by working our way through
## the tree
print(soup.head.title)
print()
# Out:
# <title>The Dormouse's story</title>

# %%
## Notice we can also get the title like so
## This is because this is the first and only title 
## in the code
print(soup.title)
# Out:
# <title>The Dormouse's story</title>

# %%
## What if I just want the text from the title?
print(soup.title.text)
# Out:
# The Dormouse's story

# %%
## What html structure is the title's parent?
print(soup.title.parent)
print(soup.title.parent.name)
# Out:
# <head><title>The Dormouse's story</title></head>
# head

# %%
## What is the first a of the html document?
print(soup.a)
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
## What is the first a's class?
print(soup.a['class'])
# Out:
# ['sister']

# %%
## There are multiple a's can I find all of them?
print(soup.find_all('a'))
for a in soup.find_all('a'):
    print()
    print(a['class'], a.text)
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
#
# ['sister'] Elsie
#
# ['sister'] Lacie
#
# ['sister'] Tillie

# %% [markdown]
# #### You Code
#
# Take a breakout session and try the following coding exercises. This may go quickly, so don't feel bad if you are unable to complete the exercise before time is up. You can always come back to finish it later!

# %%
## Find the first p of the document
## What is the first p's class? What string is in that p?


## Sample Solution
print(soup.p)
print(soup.p['class'])
print(soup.p.text)
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
# ['title']
# The Dormouse's story

# %%
## For all of the a's in the document find their href

## Sample Solution
for a in soup.find_all('a'):
    print(a['href'])
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %% [markdown]
# Now we've got some experience let's move on to some slightly more advanced parsing.
#
# ### Now We're of Drinking Age
#
# I've included in this repository some html code from an <a href = "https://untappd.com/home">Untappd</a> search. We can read in that file with the following code. I went to untappd, and found the <a href = "https://www.seventhsonbrewing.com">Seventh Son</a> page, a brewery near my apartment, then clicked on their beer list and only saved the HTML code from the results. You can see the HTML file here <a href="SeventhSon.html">SeventhSon.html</a>.

# %%
## This will save the html file's code so we can parse it

seventh_son_beer_search = open("SeventhSon.html", "r", encoding='utf8')

## this code may be un-needed, it is there in case the above code
## causes an error
#seventh_son_beer_search = open("SeventhSon.html", 'r')

## Let's look at what we just did
seventh_son_beer_search
# Out:
# <_io.TextIOWrapper name='SeventhSon.html' mode='r' encoding='utf8'>

# %%
## You write code here to make a soup object of our code
## We'll do this together, not in a breakout session
# Sample Answer
soup = BeautifulSoup(seventh_son_beer_search,"html")

# %%
## Look at the code using prettify
## Again we'll do this together, not in a breakout session
## Sample Answer
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <div class="beer-container">
#    <div class="beer-item" data-bid="382779">
#     <a class="label" href="/b/seventh-son-brewing-company-humulus-nimbus/382779">
#      <img src="https://untappd.akamaized.net/site/beer_logos/beer-382779_814af_sm.jpeg"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-humulus-nimbus/382779">
#        Humulus Nimbus
#       </a>
#      </p>
#      <p class="style">
#       Pale Ale - American
#      </p>
#      <p class="desc desc-half-382779">
#       A pale golden ale that is both super crisp and super hop forward with a refreshing mouthfeel and a summer friendly 6% abv. Mosaic &amp; simcoe hops lend tart…
#       <a class="read-more-beerlist track-click" data-bid="382779" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-382779" style="display: none;">
#       A pale golden ale that is both super crisp and super hop forward with a refreshing mouthfeel and a summer friendly 6% abv. Mosaic &amp; simcoe hops lend tart blueberry and fragrant pine to a pleasingly bitter dandelion finish. We wanted the hops to be the star in this seasonal offering taking its name from both the hop plant, Humulus Lupulus, and its light color and cloud-like feel, nimbus.
#       <br/>
#       *Pairs well with a wide range of foods from roast chicken to burgers to fish and chips, appropriate cheeses could range from a mild blue such as Gorgonzola to a traditional cheddar or Derby with Sage.
#       <a class="read-less-beerlist track-click" data-bid="382779" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       6% ABV
#      </p>
#      <p class="ibu">
#       53 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.81)
#       </span>
#      </p>
#      <p class="raters">
#       10,319 Ratings
#      </p>
#      <p class="date">
#       Added 06/10/13
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="382779" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="1388263">
#     <a class="label" href="/b/seventh-son-brewing-company-proliferous/1388263">
#      <img src="https://untappd.akamaized.net/site/beer_logos/beer-1388263_9f172_sm.jpeg"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-proliferous/1388263">
#        Proliferous
#       </a>
#      </p>
#      <p class="style">
#       IPA - Imperial / Double
#      </p>
#      <p class="desc desc-half-1388263">
#       Mosaic and a cast of supporting hops give this DIPA layers of tropical fruit and citrus with a bracing pine bitterness in the finish.
#      </p>
#      <p class="desc desc-full-1388263" style="display: none;">
#       Mosaic and a cast of supporting hops give this DIPA layers of tropical fruit and citrus with a bracing pine bitterness in the finish.
#       <a class="read-less-beerlist track-click" data-bid="1388263" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       8.3% ABV
#      </p>
#      <p class="ibu">
#       85 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r400">
#       </span>
#       <span class="num">
#        (4.03)
#       </span>
#      </p>
#      <p class="raters">
#       8,820 Ratings
#      </p>
#      <p class="date">
#       Added 01/13/16
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="1388263" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="832910">
#     <a class="label" href="/b/seventh-son-brewing-company-the-scientist/832910">
#      <img src="https://untappd.akamaized.net/site/beer_logos/beer-832910_3dc2f_sm.jpeg"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-the-scientist/832910">
#        The Scientist
#       </a>
#      </p>
#      <p class="style">
#       IPA - American
#      </p>
#      <p class="desc desc-half-832910">
#       A light bodied, hop forward IPA... constantly shifting. Each batch has one ingredient changed from the last. Expect changes as we find the right balance…
#       <a class="read-more-beerlist track-click" data-bid="832910" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-832910" style="display: none;">
#       A light bodied, hop forward IPA... constantly shifting. Each batch has one ingredient changed from the last. Expect changes as we find the right balance of hop notes
#       <a class="read-less-beerlist track-click" data-bid="832910" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       7% ABV
#      </p>
#      <p class="ibu">
#       75 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.82)
#       </span>
#      </p>
#      <p class="raters">
#       8,937 Ratings
#      </p>
#      <p class="date">
#       Added 10/04/14
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="832910" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="349430">
#     <a class="label" href="/b/seventh-son-brewing-company-seventh-son-american-strong-ale/349430">
#      <img src="https://untappd.akamaized.net/site/beer_logos/beer-349430_807bd_sm.jpeg"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-seventh-son-american-strong-ale/349430">
#        Seventh Son American Strong Ale
#       </a>
#      </p>
#      <p class="style">
#       Strong Ale - American
#      </p>
#      <p class="desc desc-half-349430">
#       A ruddy American Strong. Grapefruit and stone fruit hop aroma and character are balanced by a rich red malt backbone. A precise blend of 7 hops go into…
#       <a class="read-more-beerlist track-click" data-bid="349430" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-349430" style="display: none;">
#       A ruddy American Strong. Grapefruit and stone fruit hop aroma and character are balanced by a rich red malt backbone. A precise blend of 7 hops go into the brewing and dry hopping process including Nelson Sauvin, Mosaic, Horizon, Palisade, Citra, Wilamette, and Columbus.
#       <a class="read-less-beerlist track-click" data-bid="349430" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       7.7% ABV
#      </p>
#      <p class="ibu">
#       40 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.78)
#       </span>
#      </p>
#      <p class="raters">
#       7,572 Ratings
#      </p>
#      <p class="date">
#       Added 04/20/13
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="349430" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="358044">
#     <a class="label" href="/b/seventh-son-brewing-company-stone-fort-oat-brown/358044">
#      <img src="https://untappd.akamaized.net/site/beer_logos/beer-358044_fdb86_sm.jpeg"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-stone-fort-oat-brown/358044">
#        Stone Fort Oat Brown
#       </a>
#      </p>
#      <p class="style">
#       Brown Ale - English
#      </p>
#      <p class="desc desc-half-358044">
#       A toasty brown ale w/accessible English ale character and a smooth blend of light roast coffee, cocoa, leather biscuit flavors. Named for the oldest structure…
#       <a class="read-more-beerlist track-click" data-bid="358044" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-358044" style="display: none;">
#       A toasty brown ale w/accessible English ale character and a smooth blend of light roast coffee, cocoa, leather biscuit flavors. Named for the oldest structure in Ohio.
#       <a class="read-less-beerlist track-click" data-bid="358044" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       5.25% ABV
#      </p>
#      <p class="ibu">
#       21 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.65)
#       </span>
#      </p>
#      <p class="raters">
#       5,419 Ratings
#      </p>
#      <p class="date">
#       Added 05/04/13
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="358044" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="438596">
#     <a class="label" href="/b/seventh-son-brewing-company-oubliette/438596">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-oubliette/438596">
#        Oubliette
#       </a>
#      </p>
#      <p class="style">
#       Stout - American Imperial / Double
#      </p>
#      <p class="desc desc-half-438596">
#       Oubliette (\ˌü-blē-ˈet\) is a French term for a deep, dark forgotten dungeon devoid of light and hope. Our nearly opaque Imperial Stout is black as night…
#       <a class="read-more-beerlist track-click" data-bid="438596" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-438596" style="display: none;">
#       Oubliette (\ˌü-blē-ˈet\) is a French term for a deep, dark forgotten dungeon devoid of light and hope. Our nearly opaque Imperial Stout is black as night with hints of plum at the edges and a rich tan head. Dark cocoa and roasted malt flavors are complimented by a lingering bitterness and a pleasingly warm alcohol glow.
#       <a class="read-less-beerlist track-click" data-bid="438596" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       12% ABV
#      </p>
#      <p class="ibu">
#       99 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r400">
#       </span>
#       <span class="num">
#        (3.96)
#       </span>
#      </p>
#      <p class="raters">
#       3,432 Ratings
#      </p>
#      <p class="date">
#       Added 08/24/13
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="438596" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="1022818">
#     <a class="label" href="/b/seventh-son-brewing-company-syzygy/1022818">
#      <img src="https://untappd.akamaized.net/site/beer_logos/beer-1022818_b0c19_sm.jpeg"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-syzygy/1022818">
#        Syzygy
#       </a>
#      </p>
#      <p class="style">
#       IPA - Imperial / Double
#      </p>
#      <p class="desc desc-half-1022818">
#       Syzygy (\ˈsi-zə-jē\) Citra, Simcoe, Cascade hops. Rye malt and flaked Rye. Tasting notes: Sweet pine, tropical fruits, mandarin orange, intense dry bitter…
#       <a class="read-more-beerlist track-click" data-bid="1022818" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-1022818" style="display: none;">
#       Syzygy (\ˈsi-zə-jē\) Citra, Simcoe, Cascade hops. Rye malt and flaked Rye. Tasting notes: Sweet pine, tropical fruits, mandarin orange, intense dry bitter finish. Name is a term for many things, most notibly a celestial alignment, like an eclipse. Hard to say.
#       <br/>
#       <a class="read-less-beerlist track-click" data-bid="1022818" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       10.9% ABV
#      </p>
#      <p class="ibu">
#       100 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r400">
#       </span>
#       <span class="num">
#        (4.04)
#       </span>
#      </p>
#      <p class="raters">
#       3,294 Ratings
#      </p>
#      <p class="date">
#       Added 03/25/15
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="1022818" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="2319779">
#     <a class="label" href="/b/seventh-son-brewing-company-assistant-manager/2319779">
#      <img src="https://untappd.akamaized.net/site/beer_logos/beer-2319779_9a36a_sm.jpeg"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-assistant-manager/2319779">
#        Assistant Manager
#       </a>
#      </p>
#      <p class="style">
#       Golden Ale
#      </p>
#      <p class="desc desc-half-2319779">
#       The definition of a drinkable and refreshing. Delicate hops and golden malts give way to firm bitterness and a clean finish.
#      </p>
#      <p class="desc desc-full-2319779" style="display: none;">
#       The definition of a drinkable and refreshing. Delicate hops and golden malts give way to firm bitterness and a clean finish.
#       <a class="read-less-beerlist track-click" data-bid="2319779" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       4.5% ABV
#      </p>
#      <p class="ibu">
#       36 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r350">
#       </span>
#       <span class="num">
#        (3.57)
#       </span>
#      </p>
#      <p class="raters">
#       2,470 Ratings
#      </p>
#      <p class="date">
#       Added 10/01/17
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="2319779" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="1515633">
#     <a class="label" href="/b/seventh-son-brewing-company-goo-goo-muck-tart-ipa/1515633">
#      <img src="https://untappd.akamaized.net/site/beer_logos/beer-1515633_2254c_sm.jpeg"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-goo-goo-muck-tart-ipa/1515633">
#        Goo Goo Muck
#       </a>
#      </p>
#      <p class="style">
#       Sour - Farmhouse IPA
#      </p>
#      <p class="desc desc-half-1515633">
#       We dry hopped this kettle-soured IPA with Citra, Simcoe and Palisade for a juicy mango-grapefruit flavor and aroma. Sourness takes the place of bitterness…
#       <a class="read-more-beerlist track-click" data-bid="1515633" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-1515633" style="display: none;">
#       We dry hopped this kettle-soured IPA with Citra, Simcoe and Palisade for a juicy mango-grapefruit flavor and aroma. Sourness takes the place of bitterness in balancing out the sweetness of the malts.
#       <a class="read-less-beerlist track-click" data-bid="1515633" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       7.6% ABV
#      </p>
#      <p class="ibu">
#       50 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.81)
#       </span>
#      </p>
#      <p class="raters">
#       2,359 Ratings
#      </p>
#      <p class="date">
#       Added 04/17/16
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="1515633" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="462190">
#     <a class="label" href="/b/seventh-son-brewing-company-golden-ratio/462190">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-golden-ratio/462190">
#        Golden Ratio
#       </a>
#      </p>
#      <p class="style">
#       IPA - American
#      </p>
#      <p class="desc desc-half-462190">
#       Brewed with local honey. Galaxy, Nelson Sauvin, Moteuka hops. Tasting notes: toasty malts, tropical fruit hops.
#      </p>
#      <p class="desc desc-full-462190" style="display: none;">
#       Brewed with local honey. Galaxy, Nelson Sauvin, Moteuka hops. Tasting notes: toasty malts, tropical fruit hops.
#       <a class="read-less-beerlist track-click" data-bid="462190" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       7% ABV
#      </p>
#      <p class="ibu">
#       68 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.75)
#       </span>
#      </p>
#      <p class="raters">
#       1,780 Ratings
#      </p>
#      <p class="date">
#       Added 09/26/13
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="462190" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="2201055">
#     <a class="label" href="/b/seventh-son-brewing-company-gleen/2201055">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-gleen/2201055">
#        Gleen
#       </a>
#      </p>
#      <p class="style">
#       IPA - American
#      </p>
#      <p class="desc desc-half-2201055">
#       Northeast IPA methods and four dry hop additions meet Midwest sensibilities for a burst of pungent hoppy sunshine in this “no coast” IPA from the banks…
#       <a class="read-more-beerlist track-click" data-bid="2201055" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-2201055" style="display: none;">
#       Northeast IPA methods and four dry hop additions meet Midwest sensibilities for a burst of pungent hoppy sunshine in this “no coast” IPA from the banks of the Olentangy.
#       <a class="read-less-beerlist track-click" data-bid="2201055" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       7.9% ABV
#      </p>
#      <p class="ibu">
#       55 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r400">
#       </span>
#       <span class="num">
#        (3.91)
#       </span>
#      </p>
#      <p class="raters">
#       1,632 Ratings
#      </p>
#      <p class="date">
#       Added 07/19/17
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="2201055" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="380322">
#     <a class="label" href="/b/seventh-son-brewing-company-lost-sparrow/380322">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-lost-sparrow/380322">
#        Lost Sparrow
#       </a>
#      </p>
#      <p class="style">
#       IPA - Black / Cascadian Dark Ale
#      </p>
#      <p class="desc desc-half-380322">
#       Midnight dark, bracingly bitter yet smooth black IPA with dark malt character balanced by notes of lemon and orange rind from extensive dry hopping with…
#       <a class="read-more-beerlist track-click" data-bid="380322" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-380322" style="display: none;">
#       Midnight dark, bracingly bitter yet smooth black IPA with dark malt character balanced by notes of lemon and orange rind from extensive dry hopping with Sorachi Ace.
#       <a class="read-less-beerlist track-click" data-bid="380322" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       6.7% ABV
#      </p>
#      <p class="ibu">
#       75 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.66)
#       </span>
#      </p>
#      <p class="raters">
#       1,519 Ratings
#      </p>
#      <p class="date">
#       Added 06/07/13
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="380322" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="1868972">
#     <a class="label" href="/b/seventh-son-brewing-company-fox-in-the-stout/1868972">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-fox-in-the-stout/1868972">
#        Fox In the Stout
#       </a>
#      </p>
#      <p class="style">
#       Stout - American Imperial / Double
#      </p>
#      <p class="desc desc-half-1868972">
#       Fox in the Stout Imperial Salted Chocolate Stout: cocoa nibs and fresh vanilla beans along with flaked oats for body make this a big rich dessert stout…
#       <a class="read-more-beerlist track-click" data-bid="1868972" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-1868972" style="display: none;">
#       Fox in the Stout Imperial Salted Chocolate Stout: cocoa nibs and fresh vanilla beans along with flaked oats for body make this a big rich dessert stout worthy of its Fox in the Snow brownie inspiration.
#       <a class="read-less-beerlist track-click" data-bid="1868972" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       9.7% ABV
#      </p>
#      <p class="ibu">
#       N/A IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r425">
#       </span>
#       <span class="num">
#        (4.22)
#       </span>
#      </p>
#      <p class="raters">
#       1,501 Ratings
#      </p>
#      <p class="date">
#       Added 12/18/16
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="1868972" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="471148">
#     <a class="label" href="/b/seventh-son-brewing-company-wilderman/471148">
#      <img src="https://untappd.akamaized.net/site/beer_logos/beer-471148_140c5_sm.jpeg"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-wilderman/471148">
#        Wilderman
#       </a>
#      </p>
#      <p class="style">
#       Bière de Garde
#      </p>
#      <p class="desc desc-half-471148">
#       Inspired by the European pagan Fall tradition of Wilder Mann costumes, our Wildermann is a biere de garde with a bit more hop than French versions and…
#       <a class="read-more-beerlist track-click" data-bid="471148" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-471148" style="display: none;">
#       Inspired by the European pagan Fall tradition of Wilder Mann costumes, our Wildermann is a biere de garde with a bit more hop than French versions and clean farmhouse yeast spice. We lagered for a month which mellows the character of the beer and lets the malt shine.
#       <a class="read-less-beerlist track-click" data-bid="471148" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       7.6% ABV
#      </p>
#      <p class="ibu">
#       22 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.68)
#       </span>
#      </p>
#      <p class="raters">
#       1,443 Ratings
#      </p>
#      <p class="date">
#       Added 10/06/13
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="471148" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="581623">
#     <a class="label" href="/b/seventh-son-brewing-company-mr-owl/581623">
#      <img src="https://untappd.akamaized.net/site/beer_logos/beer-581623_72b32_sm.jpeg"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-mr-owl/581623">
#        Mr. Owl
#       </a>
#      </p>
#      <p class="style">
#       Brown Ale - Imperial / Double
#      </p>
#      <p class="desc desc-half-581623">
#       Citra, northern brewer, horizon hops. Housemade Candi Syrup. Tasting notes:rich milk chocolate, tropical fruit, orange zest. bottle release fall, named…
#       <a class="read-more-beerlist track-click" data-bid="581623" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-581623" style="display: none;">
#       Citra, northern brewer, horizon hops. Housemade Candi Syrup. Tasting notes:rich milk chocolate, tropical fruit, orange zest.
#       <br/>
#       bottle release fall, named after the tootsie roll commercial. Have fun and enjoy Mr. Owl with anything from candy-coated lollipops too spicy mole sauce, or even a foie gras torchon.
#       <a class="read-less-beerlist track-click" data-bid="581623" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       8.5% ABV
#      </p>
#      <p class="ibu">
#       73 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.79)
#       </span>
#      </p>
#      <p class="raters">
#       1,445 Ratings
#      </p>
#      <p class="date">
#       Added 02/07/14
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="581623" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="534959">
#     <a class="label" href="/b/seventh-son-brewing-company-ladies-and-gentlemen/534959">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-ladies-and-gentlemen/534959">
#        Ladies And Gentlemen
#       </a>
#      </p>
#      <p class="style">
#       Barleywine - American
#      </p>
#      <p class="desc desc-half-534959">
#       Fine carbonation carries Aromas of peach cake, clementines and flowers, balanced by a firm, Happy bitterness and hints of vanilla icing in the finish.…
#       <a class="read-more-beerlist track-click" data-bid="534959" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-534959" style="display: none;">
#       Fine carbonation carries Aromas of peach cake, clementines and flowers, balanced by a firm, Happy bitterness and hints of vanilla icing in the finish.
#       <a class="read-less-beerlist track-click" data-bid="534959" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       11% ABV
#      </p>
#      <p class="ibu">
#       51 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.82)
#       </span>
#      </p>
#      <p class="raters">
#       1,358 Ratings
#      </p>
#      <p class="date">
#       Added 12/18/13
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="534959" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="1390772">
#     <a class="label" href="/b/seventh-son-brewing-company-brother-jon/1390772">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-brother-jon/1390772">
#        Brother Jon
#       </a>
#      </p>
#      <p class="style">
#       Blonde Ale - Belgian Blonde / Golden
#      </p>
#      <p class="desc desc-half-1390772">
#       Heull Melon, Palisade Hops. A blend of two Belgian abbey style yeasts. Tasting Notes: Faint fruit and spice, crackery malt. Mild beer traditionaly brewed…
#       <a class="read-more-beerlist track-click" data-bid="1390772" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-1390772" style="display: none;">
#       Heull Melon, Palisade Hops.
#       <br/>
#       A blend of two Belgian abbey style yeasts. Tasting Notes:
#       <br/>
#       Faint fruit and spice, crackery malt. Mild beer traditionaly brewed by Belgian monks, named after a local celeb and wedding officant Jon Putnam.
#       <a class="read-less-beerlist track-click" data-bid="1390772" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       6.3% ABV
#      </p>
#      <p class="ibu">
#       30 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.63)
#       </span>
#      </p>
#      <p class="raters">
#       1,347 Ratings
#      </p>
#      <p class="date">
#       Added 01/16/16
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="1390772" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="1057580">
#     <a class="label" href="/b/seventh-son-brewing-company-chester-copperpot/1057580">
#      <img src="https://untappd.akamaized.net/site/beer_logos/beer-1057580_bb6dd_sm.jpeg"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-chester-copperpot/1057580">
#        Chester Copperpot
#       </a>
#      </p>
#      <p class="style">
#       Smoked Beer
#      </p>
#      <p class="desc desc-half-1057580">
#       Old-school German-style Hallertauer Hersbrucker, Willamette hops. Beech and Cherrywood smoked malts. Tasting notes: Sweet smokiness, clean bodied, herbal…
#       <a class="read-more-beerlist track-click" data-bid="1057580" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-1057580" style="display: none;">
#       Old-school German-style Hallertauer Hersbrucker, Willamette hops. Beech and Cherrywood smoked malts. Tasting notes: Sweet smokiness, clean bodied, herbal lingering bitterness. Goonies never say die!!
#       <a class="read-less-beerlist track-click" data-bid="1057580" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       7.9% ABV
#      </p>
#      <p class="ibu">
#       6 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.7)
#       </span>
#      </p>
#      <p class="raters">
#       1,323 Ratings
#      </p>
#      <p class="date">
#       Added 04/23/15
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="1057580" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="557738">
#     <a class="label" href="/b/seventh-son-brewing-company-willowolf/557738">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-willowolf/557738">
#        Willowolf
#       </a>
#      </p>
#      <p class="style">
#       IPA - Imperial / Double
#      </p>
#      <p class="desc desc-half-557738">
#       Amarillo, Centennial, Horizon hops. Tasting notes:bitter pine and citrus, sweet finish. named for an archaic term for the hops plant, because the vines…
#       <a class="read-more-beerlist track-click" data-bid="557738" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-557738" style="display: none;">
#       Amarillo, Centennial, Horizon hops. Tasting notes:bitter pine and citrus, sweet finish. named for an archaic term for the hops plant, because the vines can choke willow trees
#       <a class="read-less-beerlist track-click" data-bid="557738" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       9.3% ABV
#      </p>
#      <p class="ibu">
#       120 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r400">
#       </span>
#       <span class="num">
#        (3.92)
#       </span>
#      </p>
#      <p class="raters">
#       1,159 Ratings
#      </p>
#      <p class="date">
#       Added 01/11/14
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="557738" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="1309047">
#     <a class="label" href="/b/seventh-son-brewing-company-rime/1309047">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-rime/1309047">
#        Rime
#       </a>
#      </p>
#      <p class="style">
#       IPA - American
#      </p>
#      <p class="desc desc-half-1309047">
#       Lightly spiced Winter IPA uses fresh ginger, coriander, and caramelized orange peels
#      </p>
#      <p class="desc desc-full-1309047" style="display: none;">
#       Lightly spiced Winter IPA uses fresh ginger, coriander, and caramelized orange peels
#       <a class="read-less-beerlist track-click" data-bid="1309047" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       6.5% ABV
#      </p>
#      <p class="ibu">
#       53 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.78)
#       </span>
#      </p>
#      <p class="raters">
#       1,166 Ratings
#      </p>
#      <p class="date">
#       Added 11/11/15
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="1309047" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="496043">
#     <a class="label" href="/b/seventh-son-brewing-company-black-sheep/496043">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-black-sheep/496043">
#        Black Sheep
#       </a>
#      </p>
#      <p class="style">
#       Stout - Other
#      </p>
#      <p class="desc desc-half-496043">
#       This dry-hopped American stout has a full body with notes of fresh roasted coffee, cocoa and cherrywood smoke.
#      </p>
#      <p class="desc desc-full-496043" style="display: none;">
#       This dry-hopped American stout has a full body with notes of fresh roasted coffee, cocoa and cherrywood smoke.
#       <a class="read-less-beerlist track-click" data-bid="496043" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       7% ABV
#      </p>
#      <p class="ibu">
#       30 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.64)
#       </span>
#      </p>
#      <p class="raters">
#       1,096 Ratings
#      </p>
#      <p class="date">
#       Added 11/04/13
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="496043" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="1534210">
#     <a class="label" href="/b/seventh-son-brewing-company-hadron-s-collision-table-beer/1534210">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-hadron-s-collision-table-beer/1534210">
#        Hadron's Collision Table Beer
#       </a>
#      </p>
#      <p class="style">
#       Saison / Farmhouse Ale
#      </p>
#      <p class="desc desc-half-1534210">
#       Light cantaloupe aroma and flavors arrive courtesy of the singular Huell Melon hops
#      </p>
#      <p class="desc desc-full-1534210" style="display: none;">
#       Light cantaloupe aroma and flavors arrive courtesy of the singular Huell Melon hops
#       <a class="read-less-beerlist track-click" data-bid="1534210" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       3.4% ABV
#      </p>
#      <p class="ibu">
#       20 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r325">
#       </span>
#       <span class="num">
#        (3.32)
#       </span>
#      </p>
#      <p class="raters">
#       1,074 Ratings
#      </p>
#      <p class="date">
#       Added 04/30/16
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="1534210" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="1286407">
#     <a class="label" href="/b/seventh-son-brewing-company-laniakea/1286407">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-laniakea/1286407">
#        Laniakea
#       </a>
#      </p>
#      <p class="style">
#       IPA - Imperial / Double
#      </p>
#      <p class="desc desc-half-1286407">
#       Laniakea (La-ni-akea)Loads of Galaxy and Mosaic hops dominate this hugely aromatic double named for the cosmic super cluster that is home to our own Milky…
#       <a class="read-more-beerlist track-click" data-bid="1286407" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-1286407" style="display: none;">
#       Laniakea (La-ni-akea)Loads of Galaxy and Mosaic hops dominate this hugely aromatic double named for the cosmic super cluster that is home to our own Milky Way.
#       <a class="read-less-beerlist track-click" data-bid="1286407" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       9.5% ABV
#      </p>
#      <p class="ibu">
#       100 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r400">
#       </span>
#       <span class="num">
#        (3.98)
#       </span>
#      </p>
#      <p class="raters">
#       1,021 Ratings
#      </p>
#      <p class="date">
#       Added 10/24/15
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="1286407" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="1256707">
#     <a class="label" href="/b/seventh-son-brewing-company-sun-mouth/1256707">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-sun-mouth/1256707">
#        Sun Mouth
#       </a>
#      </p>
#      <p class="style">
#       Saison / Farmhouse Ale
#      </p>
#      <p class="desc desc-half-1256707">
#       This off-dry strong saison has a melange of fruit and spice flavors. Sorachi Ace and Citra hops bring dill and candied lemon while our blend of farmhouse…
#       <a class="read-more-beerlist track-click" data-bid="1256707" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-1256707" style="display: none;">
#       This off-dry strong saison has a melange of fruit and spice flavors. Sorachi Ace and Citra hops bring dill and candied lemon while our blend of farmhouse yeast layer in white pepper spice. Pilsner and wheat malts lend a bready finish. Put the sun in your mouth
#       <a class="read-less-beerlist track-click" data-bid="1256707" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       8.3% ABV
#      </p>
#      <p class="ibu">
#       30 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.66)
#       </span>
#      </p>
#      <p class="raters">
#       986 Ratings
#      </p>
#      <p class="date">
#       Added 10/01/15
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="1256707" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="1441216">
#     <a class="label" href="/b/seventh-son-brewing-company-abaddon/1441216">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-abaddon/1441216">
#        Abaddon
#       </a>
#      </p>
#      <p class="style">
#       Belgian Quad
#      </p>
#      <p class="desc desc-half-1441216">
#       Mosaic, Saaz hops. Dark housemade candi syrups, abbey yeast blend, spices. Tasting notes: Dried fruit, bitter orange, white pepper, port wine sweetness.…
#       <a class="read-more-beerlist track-click" data-bid="1441216" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-1441216" style="display: none;">
#       Mosaic, Saaz hops.
#       <br/>
#       Dark housemade candi syrups, abbey yeast blend, spices.
#       <br/>
#       Tasting notes:
#       <br/>
#       Dried fruit, bitter orange, white pepper, port wine sweetness.
#       <br/>
#       Named after a destroying angel
#       <a class="read-less-beerlist track-click" data-bid="1441216" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       10% ABV
#      </p>
#      <p class="ibu">
#       30 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.86)
#       </span>
#      </p>
#      <p class="raters">
#       971 Ratings
#      </p>
#      <p class="date">
#       Added 02/25/16
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-bid="1441216" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="1249048">
#     <a class="label" href="/b/seventh-son-brewing-company-the-wild-hunt/1249048">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-the-wild-hunt/1249048">
#        The Wild Hunt
#       </a>
#      </p>
#      <p class="style">
#       Barleywine - English
#      </p>
#      <p class="desc desc-half-1249048">
#       Inspired by the myths, legends and magic of the English countryside, this barleywine marks the transition from the exuberance of Summer to the hush of…
#       <a class="read-more-beerlist track-click" data-bid="1249048" data-href=":readmorebeer" data-track="brewerylist" href="#">
#        Read More
#       </a>
#      </p>
#      <p class="desc desc-full-1249048" style="display: none;">
#       Inspired by the myths, legends and magic of the English countryside, this barleywine marks the transition from the exuberance of Summer to the hush of Autumn. Premium English malts lend a rich body, juicy cherry notes and a deep caramel complexity. Assertively hopped when fresh, this layered ale will continue to evolve in the bottle for many years.
#       <a class="read-less-beerlist track-click" data-bid="1249048" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       9.8% ABV
#      </p>
#      <p class="ibu">
#       55 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r375">
#       </span>
#       <span class="num">
#        (3.78)
#       </span>
#      </p>
#      <p class="raters">
#       954 Ratings
#      </p>
#      <p class="date">
#       Added 09/25/15
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="1249048" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="2125648">
#     <a class="label" href="/b/seventh-son-brewing-company-qahwah-arab-imperial-coffee-stout/2125648">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-qahwah-arab-imperial-coffee-stout/2125648">
#        Qahwah Arab Imperial Coffee Stout
#       </a>
#      </p>
#      <p class="style">
#       Stout - American
#      </p>
#      <p class="desc desc-half-2125648">
#       Arab Coffee Stout. A medium bodied Imperial Stout infused with Mission Coffee beans, cardamom, clove, cinnamon and ginger.
#      </p>
#      <p class="desc desc-full-2125648" style="display: none;">
# ...
#         N/A
#        </a>
#        )
#       </span>
#      </p>
#      <p class="raters">
#       5 Ratings
#      </p>
#      <p class="date">
#       Added 01/30/19
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3059258" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="3195710">
#     <a class="label" href="/b/seventh-son-brewing-company-sike/3195710">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-sike/3195710">
#        Sike
#       </a>
#      </p>
#      <p class="style">
#       Sour - Fruited
#      </p>
#      <p class="desc desc-half-3195710">
#      </p>
#      <p class="desc desc-full-3195710" style="display: none;">
#       <a class="read-less-beerlist track-click" data-bid="3195710" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       N/A ABV
#      </p>
#      <p class="ibu">
#       N/A IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r000">
#       </span>
#       <span class="num">
#        (
#        <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#         N/A
#        </a>
#        )
#       </span>
#      </p>
#      <p class="raters">
#       6 Ratings
#      </p>
#      <p class="date">
#       Added 04/25/19
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3195710" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="3072514">
#     <a class="label" href="/b/seventh-son-brewing-company-seventh-son-saddle-lamp/3072514">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-seventh-son-saddle-lamp/3072514">
#        Seventh Son Saddle Lamp
#       </a>
#      </p>
#      <p class="style">
#       Sour - Ale
#      </p>
#      <p class="desc desc-half-3072514">
#      </p>
#      <p class="desc desc-full-3072514" style="display: none;">
#       <a class="read-less-beerlist track-click" data-bid="3072514" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       6.8% ABV
#      </p>
#      <p class="ibu">
#       N/A IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r000">
#       </span>
#       <span class="num">
#        (
#        <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#         N/A
#        </a>
#        )
#       </span>
#      </p>
#      <p class="raters">
#       5 Ratings
#      </p>
#      <p class="date">
#       Added 02/08/19
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3072514" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="3142240">
#     <a class="label" href="/b/seventh-son-brewing-company-seventh-son-stone-fort-coffee-and-vanilla-cask/3142240">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-seventh-son-stone-fort-coffee-and-vanilla-cask/3142240">
#        Seventh Son Stone Fort Coffee And Vanilla Cask
#       </a>
#      </p>
#      <p class="style">
#       Brown Ale - American
#      </p>
#      <p class="desc desc-half-3142240">
#      </p>
#      <p class="desc desc-full-3142240" style="display: none;">
#       <a class="read-less-beerlist track-click" data-bid="3142240" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       5.3% ABV
#      </p>
#      <p class="ibu">
#       N/A IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r000">
#       </span>
#       <span class="num">
#        (
#        <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#         N/A
#        </a>
#        )
#       </span>
#      </p>
#      <p class="raters">
#       5 Ratings
#      </p>
#      <p class="date">
#       Added 03/23/19
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3142240" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="3187805">
#     <a class="label" href="/b/seventh-son-brewing-company-proliferous-2019/3187805">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-proliferous-2019/3187805">
#        Proliferous 2019
#       </a>
#      </p>
#      <p class="style">
#       IPA - Imperial / Double
#      </p>
#      <p class="desc desc-half-3187805">
#      </p>
#      <p class="desc desc-full-3187805" style="display: none;">
#       <a class="read-less-beerlist track-click" data-bid="3187805" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       8.3% ABV
#      </p>
#      <p class="ibu">
#       N/A IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r000">
#       </span>
#       <span class="num">
#        (
#        <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#         N/A
#        </a>
#        )
#       </span>
#      </p>
#      <p class="raters">
#       4 Ratings
#      </p>
#      <p class="date">
#       Added 04/20/19
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3187805" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="3066342">
#     <a class="label" href="/b/seventh-son-brewing-company-scientist-5aj/3066342">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-scientist-5aj/3066342">
#        Scientist 5AJ
#       </a>
#      </p>
#      <p class="style">
#       IPA - American
#      </p>
#      <p class="desc desc-half-3066342">
#      </p>
#      <p class="desc desc-full-3066342" style="display: none;">
#       <a class="read-less-beerlist track-click" data-bid="3066342" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       7% ABV
#      </p>
#      <p class="ibu">
#       N/A IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r000">
#       </span>
#       <span class="num">
#        (
#        <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#         N/A
#        </a>
#        )
#       </span>
#      </p>
#      <p class="raters">
#       4 Ratings
#      </p>
#      <p class="date">
#       Added 02/03/19
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3066342" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="3143625">
#     <a class="label" href="/b/seventh-son-brewing-company-barrel-aged-oubliette-2019/3143625">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-barrel-aged-oubliette-2019/3143625">
#        Barrel Aged Oubliette 2019
#       </a>
#      </p>
#      <p class="style">
#       Stout - American Imperial / Double
#      </p>
#      <p class="desc desc-half-3143625">
#       Blended from ages of Oubliette that spent time in two rum barrels, two bourbon barrels and an apple brandy barrel
#      </p>
#      <p class="desc desc-full-3143625" style="display: none;">
#       Blended from ages of Oubliette that spent time in two rum barrels, two bourbon barrels and an apple brandy barrel
#       <a class="read-less-beerlist track-click" data-bid="3143625" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       13% ABV
#      </p>
#      <p class="ibu">
#       N/A IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r000">
#       </span>
#       <span class="num">
#        (
#        <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#         N/A
#        </a>
#        )
#       </span>
#      </p>
#      <p class="raters">
#       4 Ratings
#      </p>
#      <p class="date">
#       Added 03/24/19
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3143625" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="3182114">
#     <a class="label" href="/b/seventh-son-brewing-company-low-hanging-fruit/3182114">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-low-hanging-fruit/3182114">
#        Low Hanging Fruit
#       </a>
#      </p>
#      <p class="style">
#       Sour - Farmhouse IPA
#      </p>
#      <p class="desc desc-half-3182114">
#      </p>
#      <p class="desc desc-full-3182114" style="display: none;">
#       <a class="read-less-beerlist track-click" data-bid="3182114" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       7.2% ABV
#      </p>
#      <p class="ibu">
#       N/A IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r000">
#       </span>
#       <span class="num">
#        (
#        <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#         N/A
#        </a>
#        )
#       </span>
#      </p>
#      <p class="raters">
#       4 Ratings
#      </p>
#      <p class="date">
#       Added 04/17/19
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3182114" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="3148710">
#     <a class="label" href="/b/seventh-son-brewing-company-the-scientist-4al/3148710">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-the-scientist-4al/3148710">
#        The Scientist #4AL
#       </a>
#      </p>
#      <p class="style">
#       IPA - American
#      </p>
#      <p class="desc desc-half-3148710">
#      </p>
#      <p class="desc desc-full-3148710" style="display: none;">
#       <a class="read-less-beerlist track-click" data-bid="3148710" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       7% ABV
#      </p>
#      <p class="ibu">
#       70 IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r000">
#       </span>
#       <span class="num">
#        (
#        <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#         N/A
#        </a>
#        )
#       </span>
#      </p>
#      <p class="raters">
#       1 Rating
#      </p>
#      <p class="date">
#       Added 03/28/19
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3148710" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#    <div class="beer-item" data-bid="3200294">
#     <a class="label" href="/b/seventh-son-brewing-company-dang-w-pineapple-mango-and-habanero/3200294">
#      <img src="https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png"/>
#     </a>
#     <div class="beer-details">
#      <p class="name">
#       <a href="/b/seventh-son-brewing-company-dang-w-pineapple-mango-and-habanero/3200294">
#        Dang! W/ Pineapple, Mango And Habanero
#       </a>
#      </p>
#      <p class="style">
#       IPA - Imperial / Double
#      </p>
#      <p class="desc desc-half-3200294">
#       Infused
#      </p>
#      <p class="desc desc-full-3200294" style="display: none;">
#       Infused
#       <a class="read-less-beerlist track-click" data-bid="3200294" data-href=":readlessbeer" data-track="brewerylist" href="#">
#        Read Less
#       </a>
#      </p>
#     </div>
#     <div class="details">
#      <p class="abv">
#       9.7% ABV
#      </p>
#      <p class="ibu">
#       N/A IBU
#      </p>
#      <p class="rating">
#       <span class="rating small r000">
#       </span>
#       <span class="num">
#        (
#        <a class="track-click tip" data-href=":external/ratings/list" data-track="brewerylist" href="http://untp.beer/ratingshelpsite" target="_blank" title="This beer doesn't have enough ratings to have a overall rating. Click here for more info on our rating system.">
#         N/A
#        </a>
#        )
#       </span>
#      </p>
#      <p class="raters">
#       1 Rating
#      </p>
#      <p class="date">
#       Added 04/27/19
#      </p>
#     </div>
#     <a class="add wishlist list-add-enhanced track-click tip" data-href=":addwish" data-item-id="3200294" data-item-type="beer" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">
#      Add
#     </a>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# As we can see from the `prettify()` output this HTML code is more complicated than our toy example from above, but `BeautifulSoup` is able to handle it all the same. Let's write some code to go through the HTML and grab the beer names and then store those names in a list.
#
# To do that let's learn a little more about BeautifulSoup's functionality. Looking at the prettify output we see that each beer is contained in a `"beer-item"`. We can use that class information to our advantage.

# %%
## We can find all 'div's with the 'class' = "beer-item"
## by using a dictionary argument to find_all
cooler = soup.find_all('div',{'class':"beer-item"})

# %%
cooler[0]
# Out:
# <div class="beer-item" data-bid="382779">
# <a class="label" href="/b/seventh-son-brewing-company-humulus-nimbus/382779">
# <img src="https://untappd.akamaized.net/site/beer_logos/beer-382779_814af_sm.jpeg"/>
# </a><div class="beer-details">
# <p class="name"><a href="/b/seventh-son-brewing-company-humulus-nimbus/382779">Humulus Nimbus </a></p>
# <p class="style">Pale Ale - American</p>
# <p class="desc desc-half-382779">A pale golden ale that is both super crisp and super hop forward with a refreshing mouthfeel and a summer friendly 6% abv. Mosaic &amp; simcoe hops lend tart… <a class="read-more-beerlist track-click" data-bid="382779" data-href=":readmorebeer" data-track="brewerylist" href="#">Read More</a> </p>
# <p class="desc desc-full-382779" style="display: none;">A pale golden ale that is both super crisp and super hop forward with a refreshing mouthfeel and a summer friendly 6% abv. Mosaic &amp; simcoe hops lend tart blueberry and fragrant pine to a pleasingly bitter dandelion finish. We wanted the hops to be the star in this seasonal offering taking its name from both the hop plant, Humulus Lupulus, and its light color and cloud-like feel, nimbus. <br/>
# *Pairs well with a wide range of foods from roast chicken to burgers to fish and chips, appropriate cheeses could range from a mild blue such as Gorgonzola to a traditional cheddar or Derby with Sage. <a class="read-less-beerlist track-click" data-bid="382779" data-href=":readlessbeer" data-track="brewerylist" href="#">Read Less</a></p>
# </div>
# <div class="details">
# <p class="abv">
# 6% ABV </p><p class="ibu">
# 53 IBU </p><p class="rating">
# <span class="rating small r375"></span>
# <span class="num">(3.81)</span> </p><p class="raters">
# 10,319 Ratings </p><p class="date">
# Added 06/10/13 </p>
# </div>
# <a class="add wishlist list-add-enhanced track-click tip" data-bid="382779" data-href=":addwish" data-track="brewerylist" data-wishlist="add" href="#" title="Add to List">Add</a> </div>

# %%
len(cooler)
# Out:
# 113

# %%
## Now we can use what we just learned to extract the name from the first beer
## The name is contained in a p element with class "name"
print(cooler[0].find("p",{'class':"name"}).text)
# Out:
# Humulus Nimbus

# %%
## Using a list comprehension we can make a list that contains
## all of the beer names
beer_names = [beer.find("p",{'class':"name"}).text for beer in cooler]

# %%
for beer in beer_names[:5]:
    print(beer)
# Out:
# Humulus Nimbus
# Proliferous
# The Scientist
# Seventh Son American Strong Ale
# Stone Fort Oat Brown

# %% [markdown]
# #### You Code
#
# You've been hired by a competitor to SeventhSon. They want a dataframe of all of SeventhSon's beers that includes their name, beer type, abv, and ibu. Use `BeautifulSoup` to give them this.
#
# Again these sessions can go quickly, so it's okay if you're unable to complete it right now. Just try your best, and you can always finish it later!

# %%
## Your Code here

## Sample Answer
beers = [beer.find("p",{'class':"name"}).text for beer in cooler]
types = [beer.find("p",{'class':"style"}).text for beer in cooler]
ibus = [beer.find("p",{'class':"ibu"}).text.replace("\n","").replace(" IBU","") for beer in cooler]
abvs = [beer.find("p",{'class':"abv"}).text.replace("\n","").replace(" ABV","") for beer in cooler]




beer_df = pd.DataFrame({'name':beers,'type':types,'ibu':ibus,'abv':abvs})

beer_df.head(10)
# Out:
#                               name                                type   ibu  \
# 0                  Humulus Nimbus                  Pale Ale - American   53
# 1                      Proliferous             IPA - Imperial / Double   85
# 2                    The Scientist                      IPA - American   75
# 3  Seventh Son American Strong Ale               Strong Ale - American   40
# 4             Stone Fort Oat Brown                 Brown Ale - English   21
# 5                        Oubliette  Stout - American Imperial / Double   99
# 6                           Syzygy             IPA - Imperial / Double  100
# 7                Assistant Manager                          Golden Ale   36
# 8                     Goo Goo Muck                Sour - Farmhouse IPA   50
# 9                     Golden Ratio                      IPA - American   68
#
#       abv
# 0     6%
# 1   8.3%
# 2     7%
# 3   7.7%
# 4  5.25%
# 5    12%
# 6  10.9%
# 7   4.5%
# 8   7.6%
# 9     7%

# %%
## You Code
## Use pandas to find how many of each type of beer
## exist in the data set

## Sample Answer
beer_df.type.value_counts()
# Out:
# IPA - American                          17
# Saison / Farmhouse Ale                  11
# IPA - Imperial / Double                  9
# Pale Ale - American                      7
# IPA - New England                        6
# IPA - Brut                               4
# Smoked Beer                              4
# Stout - American Imperial / Double       4
# Sour - Farmhouse IPA                     3
# Pale Ale - New England                   3
# IPA - Black / Cascadian Dark Ale         3
# Stout - Imperial / Double                3
# Lager - IPL (India Pale Lager)           2
# Lager - Euro                             2
# Bière de Garde                           2
# Stout - American                         2
# Barleywine - American                    2
# Blonde Ale - Belgian Blonde / Golden     2
# Brown Ale - English                      1
# Belgian Tripel                           1
# Dark Ale                                 1
# Witbier                                  1
# Barleywine - English                     1
# Pale Ale - Belgian                       1
# Fruit Beer                               1
# Belgian Quad                             1
# Stout - Coffee                           1
# IPA - White                              1
# Stout - Milk / Sweet                     1
# Sour - Fruited                           1
# Stout - Foreign / Export                 1
# Strong Ale - American                    1
# Golden Ale                               1
# Brown Ale - American                     1
# Stout - Other                            1
# Pale Ale - International                 1
# Brown Ale - Imperial / Double            1
# Porter - Baltic                          1
# Blonde Ale                               1
# English Mild Ale                         1
# Sour - Ale                               1
# Belgian Dubbel                           1
# Strong Ale - English                     1
# IPA - Belgian                            1
# IPA - Session / India Session Ale        1
# Name: type, dtype: int64

# %% [markdown]
# Great! We're finally getting familiar enough with BeautifulSoup to move on to an actual website.

# %% [markdown]
# ### Surfing the web
#
# Here's our hypothetical project. You're hired by someone that wants to start a FiveThirtyEight like website, but hates writing. Their goal is to create a natural language bot that uses an Natural Language Processing algorithm to generate new 538 like articles using previous 538 articles. They're too busy working on the algorithm so they've outsourced the job of scraping the article content to us.
#
# Their desired output is a compilation of 538's articles. The data they need is each article's title, author, and text.
#
# Let's go through how to get the title, author, and text for one specific article.
#
# Let's try this article, <a href="https://fivethirtyeight.com/features/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense/">The Mavericks Bet Big On Kristaps Porziņģis. It’s Paying Off On Offense, But What About Defense?</a>.

# %%
## This will let us to get the html code from 538
from urllib.request import urlopen

# %%
## First we'll tell python to grab the html code for us
html = urlopen("https://fivethirtyeight.com/features/" +
               "the-mavericks-bet-big-on-kristaps-porzingis" +
               "-its-paying-off-on-offense-but-what-about-defense/")

# %%
## Then we make it into a soup object
soup = BeautifulSoup(html,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <script src="https://dcf.espn.com/TWDC-DTCI/prod/Bootstrap.js">
#   </script>
#   <title>
#    The Mavericks Bet Big On Kristaps Porziņģis. It’s Paying Off On Offense, But What About Defense? | FiveThirtyEight
#   </title>
#   <!-- Jetpack Site Verification Tags -->
#   <link as="font" crossorigin="anonymous" href="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/assets/fonts/AtlasGrotesk-Bold-Web.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/assets/fonts/AtlasGrotesk-Regular-Web.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/assets/fonts/decimamonopro-webfont.woff2" rel="preload" type="font/woff2"/>
#   <link href="//cdn.registerdisney.go.com" rel="dns-prefetch">
#    <link href="//platform.twitter.com" rel="dns-prefetch">
#     <link href="//s.w.org" rel="dns-prefetch">
#      <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
#      <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#      <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
#      <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
#      <link href="//www.googletagservices.com" rel="dns-prefetch"/>
#      <link href="//www.googleadservices.com" rel="dns-prefetch"/>
#      <link href="//adservice.google.com" rel="dns-prefetch"/>
#      <link href="//www.google.com" rel="dns-prefetch"/>
#      <link href="https://fivethirtyeight.com/_static/??-eJxtzeEKgzAMBOAXWs1EcPhj7Fm0xhqWpsVER99+hTEYst939x28siPxvM+o4FVhJjWYOPmnY5q2cSugVhibSNLUwgXqwicxFIPMeyBRCLS4zGNx026WBEZVtI93iv4ytmKs96hZ3EIH2kqbFaSw2i91ir7UI97bvr0N127ouzcxBk2y" id="all-css-0" media="all" rel="stylesheet" type="text/css"/>
#      <style id="wp-block-library-inline-css">
#       .has-text-align-justify{text-align:justify;}
#      </style>
#      <script id="disney-oneid-js-extra">
#       var DisneyOneID = {"config":{"clientId":"DATG-FIVETHIRTYEIGHT.WEB-PROD","langPref":"en-US","debug":false,"responderPage":"https:\/\/fivethirtyeight.com\/oneid-responder","campaignName":"FiveThirtyEight"}};
#      </script>
#      <script id="disney-oneid-js" src="https://cdn.registerdisney.go.com/v2/outer/DisneyID.js?clientID=DATG-FIVETHIRTYEIGHT.WEB-PROD">
#      </script>
#      <script id="taboola-js-extra">
#       var ESPNTaboola = {"publisher":"abcnews-fivethirtyeight","type":"article"};
#      </script>
#      <script src="https://fivethirtyeight.com/_static/??-" type="text/javascript">
#      </script>
#      <script async="async" defer="defer" id="platform-twitter-js" src="https://platform.twitter.com/widgets.js?ver=1.0.24">
#      </script>
#      <script id="abc-analytics-js-extra">
#       var ABCAnalytics = {"nielsen":{"asset_id":307707,"section":"sportsnba","seg_a":"","seg_b":"","seg_c":"","debug":""},"chartbeat":{"uid":"12240","domain":"fivethirtyeight.com","path":"\/features\/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense\/","sections":"sports,features","authors":"Jared Dubin","title":"The Mavericks Bet Big On Kristaps Porzi\u0146\u0123is. It\u2019s Paying Off On Offense, But What About Defense?","loadPubJS":false,"loadVidJS":true},"gtm":{"id":"GTM-KLHT6T2"},"omniture":{"pageName":"sports:features:the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense","prop1":"fivethirtyeight","prop2":"","prop5":"features","prop6":"Jared Dubin","prop7":"sports","prop8":"sports:nba","prop12":"The Mavericks Bet Big On Kristaps Porzi\u0146\u0123is. It\u2019s Paying Off On Offense, But What About Defense?","prop13":"307707:The Mavericks Bet Big On Kristaps Porzi\u0146\u0123is. It\u2019s Paying Off On Offense, But What About Defense?","prop14":"","prop15":"https:\/\/fivethirtyeight.com\/features\/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense\/","prop16":"https:\/\/fivethirtyeight.com\/features\/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense\/","prop20":"Desktop","prop23":"Dallas Mavericks, Kristaps Porzingis, Luka Doncic, NBA, Pick-And-Roll","eVar5":"features","eVar6":"Jared Dubin","eVar7":"sports","eVar8":"sports:nba","eVar9":"2021-04-14","eVar10":"14:46","eVar12":"The Mavericks Bet Big On Kristaps Porzi\u0146\u0123is. It\u2019s Paying Off On Offense, But What About Defense?","eVar13":"307707:The Mavericks Bet Big On Kristaps Porzi\u0146\u0123is. It\u2019s Paying Off On Offense, But What About Defense?","eVar14":"","eVar15":"https:\/\/fivethirtyeight.com\/features\/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense\/","eVar16":"https:\/\/fivethirtyeight.com\/features\/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense\/","eVar20":"Desktop","eVar21":null,"eVar22":null,"prop35":"2021-04-14"},"account":"wdgnewfivethirtyeight"};
#      </script>
#      <script src="https://fivethirtyeight.com/wp-content/plugins/abc-analytics/assets/js/analytics.min.js?m=1612892654g" type="text/javascript">
#      </script>
#      <link href="https://fivethirtyeight.com/wp-json/" rel="https://api.w.org/"/>
#      <link href="https://fivethirtyeight.com/wp-json/wp/v2/fte_features/307707" rel="alternate" type="application/json"/>
#      <link href="https://fivethirtyeight.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#      <link href="https://fivethirtyeight.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#      <meta content="WordPress 5.6.2" name="generator">
#       <link href="https://53eig.ht/2QjRAr6" rel="shortlink"/>
#       <link href="https://fivethirtyeight.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ffivethirtyeight.com%2Ffeatures%2Fthe-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense%2F" rel="alternate" type="application/json+oembed"/>
#       <link href="https://fivethirtyeight.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ffivethirtyeight.com%2Ffeatures%2Fthe-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#       <style>
#        .getty.aligncenter {
#             text-align: center;
#         }
#         .getty.alignleft {
#             float: none;
#             margin-right: 0;
#         }
#         .getty.alignleft > div {
#             float: left;
#             margin-right: 5px;
#         }
#         .getty.alignright {
#             float: none;
#             margin-left: 0;
#         }
#         .getty.alignright > div {
#             float: right;
#             margin-left: 5px;
#         }
#       </style>
#       <style type="text/css">
#        img#wpstats{display:none}
#       </style>
#       <link href="https://fivethirtyeight.com/features/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense/amp/" rel="amphtml"/>
#       <!-- Jetpack Open Graph Tags -->
#       <meta content="article" property="og:type">
#        <meta content="The Mavericks Bet Big On Kristaps Porziņģis. It’s Paying Off On Offense, But What About Defense?" property="og:title"/>
#        <meta content="https://fivethirtyeight.com/features/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense/" property="og:url"/>
#        <meta content="Kristaps Porziņģis has found his offensive form. Can he do the same on defense?" property="og:description"/>
#        <meta content="2021-04-14T18:46:58+00:00" property="article:published_time"/>
#        <meta content="2021-04-14T18:46:58+00:00" property="article:modified_time"/>
#        <meta content="FiveThirtyEight" property="og:site_name"/>
#        <meta content="https://fivethirtyeight.com/wp-content/uploads/2021/04/AP21099077651088-16x9-1.jpg?w=700" property="og:image"/>
#        <meta content="700" property="og:image:width"/>
#        <meta content="394" property="og:image:height"/>
#        <meta content="en_US" property="og:locale"/>
#        <meta content="https://fivethirtyeight.com/contributors/jared-dubin/" property="article:author"/>
#        <meta content="https://www.facebook.com/fivethirtyeight" property="article:publisher"/>
#        <meta content="797620670264818" property="fb:app_id"/>
#        <meta content="687958677914631" property="fb:pages"/>
#        <meta content="FiveThirtyEight" name="twitter:site"/>
#        <meta content="2303751216" name="twitter:site:id"/>
#        <meta content="on" name="twitter:widgets:csp"/>
#        <meta content="300" name="twitter:maxage"/>
#        <meta content="summary_large_image" name="twitter:card"/>
#        <meta content="JADubin5" name="twitter:creator"/>
#        <meta content="176909855" name="twitter:creator:id"/>
#        <meta content="https://fivethirtyeight.com/wp-content/uploads/2021/04/AP21099077651088-16x9-1.jpg?w=700" name="twitter:image:src"/>
#        <meta content="Written by" name="twitter:label1"/>
#        <meta content="Jared Dubin" name="twitter:data1"/>
#        <meta content="Filed under" name="twitter:label2"/>
#        <meta content="Dallas Mavericks, Kristaps Porzingis, Luka Doncic, NBA, Pick-And-Roll" name="twitter:data2"/>
#        <!-- End Jetpack Open Graph Tags -->
#        <meta content="2021-04-14T18:46:58+00:00" name="DC.date.issued"/>
#        <meta content="Kristaps Porziņģis has found his offensive form. Can he do the same on defense?" name="description"/>
#        <meta content="Jared Dubin" name="author"/>
#        <link href="https://fivethirtyeight.com/contributors/jared-dubin/" rel="author">
#         <link href="https://fivethirtyeight.com/contributors/jared-dubin/feed/" rel="alternate" title="Posts feed for Jared Dubin" type="application/rss+xml"/>
#         <link href="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/humans.txt" rel="author" type="text/plain">
#          <link href="https://fivethirtyeight.com/features/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense/" rel="canonical"/>
#          <script type="application/ld+json">
#           {"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https://fivethirtyeight.com/features/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense/"},"headline":"The Mavericks Bet Big On Kristaps Porziņģis. It&#8217;s Paying Off On Offense, But What About Defense?","datePublished":"2021-04-14T14:46:58-04:00","dateModified":"2021-04-15T12:52:57-04:00","publisher":{"@type":"Organization","name":"FiveThirtyEight","logo":{"url":"https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/assets/images/fivethirtyeight-logo-rich-snippets.png","height":60,"width":546,"@type":"ImageObject"}},"author":{"@type":"Person","name":"Jared Dubin"},"articleSection":"Sports","image":{"@type":"ImageObject","url":"https://fivethirtyeight.com/wp-content/uploads/2021/04/AP21099077651088-4x3-1.jpg?w=1024","width":1024,"height":768}}
#          </script>
#          <style id="wp-custom-css" type="text/css">
#           section.viz {
# background-color: #fff;
# }
# div.liveblog-entry-content>header.single-post-header{
# display: none;
# }
#          </style>
#          <link color="#ed713a" href="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/assets/images/logo-fox-head-black.svg?v=1.0.24" rel="mask-icon"/>
#          <link href="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/assets/images/favicon.ico?v=1.0.24" rel="shortcut icon"/>
#          <link href="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/assets/images/fivethirtyeight-logo-touch.png?v=1.0.24" rel="apple-touch-icon"/>
#         </link>
#        </link>
#       </meta>
#      </meta>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="fte_features-template-default single single-fte_features postid-307707 vertical-sports slug-the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense topic-slug-nba">
#   <a class="skip-to-content-link visually-hidden" href="#content">
#    Skip to main content
#   </a>
#   <div class="master-ad" id="masterad">
#    <div class="ad-banner" data-defer="none" id="ad-Banner">
#    </div>
#   </div>
#   <!-- #masterad -->
#   <i class="header-global-bground">
#   </i>
#   <header class="header-global" id="header-global">
#    <div class="site-wrapper header-global-top">
#     <h2 class="header-global-logo">
#      <a class="header-global-logo-link" href="/" name="&amp;lpos=fivethirtyeight&amp;lid=Header Home">
#       <span class="visually-hidden">
#        FiveThirtyEight
#       </span>
#       <svg class="site-logo" height="163.451" viewbox="0 318.275 1280 163.451" width="1280" xmlns="http://www.w3.org/2000/svg">
#        <path d="M0 318.275h76.009v24.323H27.363v30.403h45.606v24.323H27.363v51.687H0zm94.252 109.453h15.202v-54.727H94.252v-24.323h39.525v79.05h12.162v21.283H94.252v-21.283zm15.202-109.453h24.323v24.323h-24.323v-24.323zm434.774 109.453h15.202v-54.727h-15.202v-24.323h39.525v79.05h12.162v21.283h-51.686v-21.283zm15.202-109.453h24.323v24.323H559.43v-24.323zm401.33 109.453h15.202v-54.727H960.76v-24.323h39.525v79.05h12.161v21.283H960.76v-21.283zm15.202-109.453h24.323v24.323h-24.323v-24.323zm-811.781 82.09v-51.687h24.323v45.606l12.161 30.343h3.04l12.162-30.343v-45.606h24.323v51.687l-21.283 48.646h-33.444zm173.301 48.646h-41.288c-24.901 0-37.762-11.584-37.762-35.968v-27.88c0-23.016 13.074-39.525 39.525-39.525 28.367 0 39.525 15.415 39.525 42.565v21.283h-51.686v5.29c0 7.966 3.04 12.952 10.398 12.952h41.288v21.283zm-51.686-60.808h24.323v-4.713c0-7.966-3.223-16.57-12.557-16.57-8.483 0-11.766 6.689-11.766 16.57v4.713zm94.251-45.605h-30.403v-24.323h88.171v24.323h-30.404v106.413h-27.364zm234.11 106.413V348.678h24.323v12.161c3.466-7.449 11.401-12.161 21.952-12.161h8.452v24.323h-18.242c-8.635 0-12.161 2.858-12.161 11.857v64.152h-24.324zm130.736 0h-14.715c-21.617 0-30.89-11.219-30.89-33.9v-42.109h-18.242v-24.323h18.242v-21.283h24.323v21.283h21.283v24.323H723.61l-.213 42.353c0 6.75 2.828 12.374 11.128 12.374h10.368v21.282zm535.107 0h-14.715c-21.617 0-30.89-11.219-30.89-33.9v-42.109h-18.242v-24.323h18.242v-21.283h24.323v21.283H1280v24.323h-21.283l-.213 42.353c0 6.75 2.828 12.374 11.128 12.374H1280v21.282zm-506.953 32.714l14.016-28.883-23.928-52.477v-51.687h24.323v45.606l12.162 30.404h3.04l12.162-30.404v-45.606h24.323v51.687l-37.397 81.36zm90.421-163.45h76.009v24.323h-48.646v27.363h45.606v24.323h-45.606v30.404h48.646v24.323h-76.009zm161.14 145.938v-6.081h48.95c6.081 0 8.817-.547 8.817-3.861v-1.034c0-3.284-2.767-4.226-8.817-4.226h-39.829v-15.202l15.202-15.202c-16.084-4.5-24.323-16.509-24.323-33.444v-3.04c0-22.985 13.499-36.485 42.565-36.485a66.672 66.672 0 0 1 18.09 3.04l12.313-18.242 15.202 9.121-12.161 18.242c4.165 5.868 9.121 14.989 9.121 24.323v3.04c0 21.283-10.033 32.41-36.484 33.444l-9.121 12.161h18.242c17.999 0 27.363 7.966 27.363 23.35v.334c0 15.384-8.239 24.962-26.208 24.962h-39.525c-13.043.002-19.397-5.593-19.397-15.2zm57.767-76.01v-9.121c0-10.033-4.044-12.161-15.202-12.161-11.158 0-15.202 2.128-15.202 12.161v9.121c0 10.033 4.226 12.162 15.202 12.162s15.202-2.128 15.202-12.162zm72.969 60.808h-24.323V318.275h24.323v42.565c3.466-8.118 10.337-12.161 21.283-12.161 19.033 0 27.363 9.364 27.363 32.714v67.618h-24.323v-63.848c0-9.516-3.253-15.202-12.162-15.202-8.908 0-12.161 5.686-12.161 15.202v63.848zm-678.004 0h-24.323V318.275h24.323v42.565c3.466-8.118 11.888-12.161 22.772-12.161 19.033 0 25.874 9.516 25.874 32.867v67.466h-24.323v-66.888c0-9.516-3.253-13.499-12.161-13.499s-12.162 6.871-12.162 16.388v63.998z">
#        </path>
#       </svg>
#       <img alt="FiveThirtyEight" class="site-logo-small" height="55" id="site-logo-small" src="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/assets/images/logo-fox-head-color.svg" width="57"/>
#      </a>
#     </h2>
#     <form action="https://fivethirtyeight.com/" class="search-form" id="searchform" method="get">
#      <label class="search-form-label" for="search-field">
#       Search
#      </label>
#      <div class="search-form-input-wrapper">
#       <input class="search-form-input" id="search-field" name="s" placeholder="Search" tabindex="-1" type="search"/>
#      </div>
#      <input class="search-form-submit" tabindex="-1" type="submit" value="Search"/>
#      <button aria-label="Search" class="search-button" id="search-button">
#       <span class="visually-hidden">
#        Search
#       </span>
#      </button>
#     </form>
#     <a class="header-espn-link" href="https://abcnews.go.com/" name="&amp;lpos=fivethirtyeightHeader&amp;lid=Header ABC News" rel="noopener" target="_blank" title="ABC News">
#      <svg height="23" width="65" xmlns="http://www.w3.org/2000/svg">
#       <path d="M25.089 6.709c-.47-.496-.974-.798-1.322-.798h-.313v-.275h.261c.121 0 1.548.058 1.687.058.227 0 .886-.058 1.026-.058h.278l6.618 7.345V7.187c0-.921-.4-1.276-1.407-1.276h-.296v-.275h.313c.035 0 1.529.058 1.65.058.173 0 1.164-.058 1.355-.058h.192l.017.275c-.922.071-1.165.32-1.165 1.135v9.16h-.312l-7.904-8.77v6.6c0 1.384.314 1.756 1.46 1.756h.295v.296h-.331c-.243 0-1.441-.06-1.72-.06-.156 0-1.269.06-1.512.06h-.279v-.296c1.166-.107 1.41-.302 1.41-1.153v-7.93h-.001zm11.98.106c0-.691-.261-.904-1.079-.904h-.26v-.275h.678c.47 0 3.008.058 3.026.058.364 0 2.777-.058 3.296-.058h.695l.035 2.277h-.27c-.053-1.188-.58-1.667-1.795-1.667h-2.43v4.026h2.1c.816 0 1.268-.39 1.389-1.225l.31.018v3.178h-.293c-.138-.993-.642-1.383-1.857-1.383h-1.666v3.672c0 .603.296.905.885.905h1.736c1.126 0 1.944-.515 2.43-1.58h.314l-.731 2.23c-.505 0-2.898-.058-3.696-.058-.539 0-3.13.04-3.722.058h-.452v-.295h.278c.818-.017 1.08-.23 1.08-.923V6.815zm16.701 9.41h-.487l-1.984-5.511-2.035 5.512h-.47L45.4 6.975c-.26-.71-.505-.993-.957-1.08v-.26h.296c.191 0 1.149.059 1.375.059.191 0 1.182-.058 1.391-.058h.314v.275c-.505.019-.714.16-.714.443 0 .16.052.39.14.639l2.383 6.557 1.357-3.74-.887-2.516c-.383-1.081-.714-1.364-1.55-1.383v-.275h.28c.243 0 1.496.058 1.793.058.242 0 1.495-.058 1.773-.058h.417v.275h-.417c-.574 0-.852.142-.852.443 0 .16.07.444.174.727l2.314 6.522 1.827-5.53c.226-.709.33-1.17.33-1.453 0-.496-.243-.71-.782-.71h-.313v-.274h.087c.243 0 .851.058 1.217.058.173 0 .851-.058 1.18-.058h.123v.275c-.436.125-.66.443-1.007 1.525l-2.923 8.79zm4.01-2.563c.278.688.52 1.008.988 1.361.59.46 1.37.69 2.237.69 1.491 0 2.497-.796 2.497-1.946 0-.85-.486-1.31-2.282-2.175-1.74-.85-2.174-1.274-2.538-1.628-.537-.584-.762-1.114-.762-1.822 0-1.627 1.3-2.704 3.265-2.704.592 0 1.236.088 1.933.264.278.07.557.106.714.106.138 0 .209-.035.26-.153h.3l.034 2.229h-.247c-.156-.531-.26-.76-.487-1.05-.488-.585-1.254-.903-2.237-.903-1.248 0-2.064.601-2.064 1.504 0 .778.47 1.22 2.134 1.998 2.134 1.008 3.426 1.911 3.426 3.573 0 1.91-1.537 3.2-3.807 3.2a8.04 8.04 0 0 1-1.838-.229 3.676 3.676 0 0 0-.624-.089c-.209 0-.277.036-.415.2h-.295l-.035-.248c-.118-.7-.258-1.398-.418-2.09l.261-.089zM3.97 9.732c-.262 0-.51.06-.73.168-.587.291-.957.89-.955 1.546 0 .946.755 1.714 1.684 1.714.931 0 1.684-.768 1.684-1.714 0-.947-.753-1.715-1.684-1.715zm7.259 0c-.93 0-1.685.767-1.685 1.714 0 .946.754 1.714 1.685 1.714.93 0 1.684-.768 1.684-1.714 0-.947-.755-1.715-1.684-1.715z">
#       </path>
#       <path d="M18.47 14.875c-1.862 0-3.37-1.535-3.37-3.43 0-1.893 1.508-3.428 3.37-3.428 1.596 0 2.932 1.132 3.28 2.65h-1.78a1.68 1.68 0 0 0-1.5-.936c-.932 0-1.686.768-1.686 1.715 0 .946.754 1.714 1.685 1.714a1.68 1.68 0 0 0 1.502-.94l1.783-.017c-.339 1.53-1.68 2.672-3.285 2.672zm-7.241 0c-1.853 0-3.356-1.522-3.369-3.405l-.04-6.016h1.704l.01 3.228c.499-.396 1.077-.665 1.695-.665 1.86 0 3.368 1.535 3.368 3.429s-1.509 3.429-3.368 3.429zm-5.546 0l-.007-.859c-.382.389-1.043.859-1.824.859-1.86 0-3.251-1.535-3.251-3.43 0-1.893 1.508-3.428 3.368-3.428.29 0 .573.037.843.108 1.453.38 2.526 1.723 2.526 3.32v.01l.02 3.42H5.682zM11.229.017C5.027.017 0 5.134 0 11.446s5.027 11.43 11.229 11.43c6.2 0 11.228-5.118 11.228-11.43 0-6.312-5.028-11.429-11.228-11.429z">
#       </path>
#      </svg>
#     </a>
#     <span class="nav-global-toggle" id="nav-global-toggle">
#      Menu
#     </span>
#    </div>
#    <div class="single-sticky">
#     <div class="single-sticky-vertical">
#     </div>
#     <div class="single-sticky-title">
#      The Mavericks Bet Big On Kristaps Porziņģis. It’s Paying Off On Offense, But What About Defense?
#     </div>
#     <a class="button share-sticky sticky-facebook" href="https://fivethirtyeight.com/features/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense/?share=facebook">
#      Share on Facebook
#     </a>
#     <a class="button share-sticky sticky-twitter" href="https://fivethirtyeight.com/features/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense/?share=twitter">
#      Share on Twitter
#     </a>
#    </div>
#    <div class="site-wrapper header-global-bottom">
#     <nav class="nav-global" id="nav-global">
#      <ul class="nav-global-menu">
#       <li class="nav-global-menu-item menu-politics">
#        <a href="https://fivethirtyeight.com/politics/" name="&amp;lpos=fivethirtyeight&amp;lid=Header Politics">
#         Politics
#        </a>
#       </li>
#       <li class="nav-global-menu-item menu-sports -current-vertical">
#        <a href="https://fivethirtyeight.com/sports/" name="&amp;lpos=fivethirtyeight&amp;lid=Header Sports">
#         Sports
#        </a>
#       </li>
#       <li class="nav-global-menu-item menu-science">
#        <a href="https://fivethirtyeight.com/science/" name="&amp;lpos=fivethirtyeight&amp;lid=Header Science">
#         Science
#        </a>
#       </li>
#       <li class="nav-global-menu-item menu-podcast">
#        <a href="https://fivethirtyeight.com/podcasts/" name="&amp;lpos=fivethirtyeight&amp;lid=Header Podcasts">
#         Podcasts
#        </a>
#       </li>
#       <li class="nav-global-menu-item menu-video">
#        <a href="https://fivethirtyeight.com/videos/" name="&amp;lpos=fivethirtyeight&amp;lid=Header Video">
#         Video
#        </a>
#       </li>
#       <li class="nav-global-menu-item menu-abcn -mobile-only">
#        <a href="https://abcnews.go.com/" name="&amp;lpos=fivethirtyeightHeader&amp;lid=Header ABC News" rel="noopener">
#         ABC News
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <!-- #nav-global -->
#    </div>
#    <!-- .site-wrapper -->
#   </header>
#   <!-- #header-global -->
#   <div class="site-main">
#    <div class="site-wrapper" id="wrapper">
#     <div class="single single-feature" data-col="2" id="content">
#      <div class="single-feature__row">
#       <div class="single-feature__col" id="primary">
#        <div id="article-main">
#         <article class="post-307707 fte_features type-fte_features status-publish has-post-thumbnail hentry tag-dallas-mavericks tag-kristaps-porzingis tag-luka-doncic tag-nba tag-pick-and-roll espn_verticals-sports vertical-sports topic-slug-nba" id="post-307707">
#          <header class="post-info single-post-header">
#           <p class="topic single-topic">
#            <time class="datetime">
#             Apr. 14, 2021
#            </time>
#            ,
# 								at
#            <time class="datetime updated" title="2021-04-14T18:46:58+00:00">
#             2:46 PM
#            </time>
#           </p>
#           <div class="single-header">
#            <h1 class="article-title article-title-single entry-title">
#             The Mavericks Bet Big On Kristaps Porziņģis. It’s Paying Off On Offense, But What About Defense?
#            </h1>
#           </div>
#           <div class="single-header-metadata-and-share-wrap">
#            <div class="single-header-metadata-wrap">
#             <p class="single-metadata single-byline vcard">
#              By
#              <a class="author url fn" href="https://fivethirtyeight.com/contributors/jared-dubin/" rel="author" title="">
#               Jared Dubin
#              </a>
#             </p>
#             <p class="single-metadata single-topic">
#              Filed under
#              <a class="term" href="https://fivethirtyeight.com/tag/nba/" name="">
#               NBA
#              </a>
#             </p>
#            </div>
#            <div class="share">
#             <div class="sharedaddy sd-sharing-enabled">
#              <div class="robots-nocontent sd-block sd-social sd-social-icon-text sd-sharing">
#               <div class="sd-content">
#                <ul>
#                 <li class="share-facebook">
#                  <a class="share-facebook sd-button share-icon" data-shared="sharing-facebook-307707" href="https://fivethirtyeight.com/features/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense/?share=facebook" rel="nofollow noopener noreferrer" target="_blank" title="Click to share on Facebook">
#                   <span>
#                    Facebook
#                   </span>
#                  </a>
#                 </li>
#                 <li class="share-twitter">
#                  <a class="share-twitter sd-button share-icon" data-shared="sharing-twitter-307707" href="https://fivethirtyeight.com/features/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense/?share=twitter" rel="nofollow noopener noreferrer" target="_blank" title="Click to share on Twitter">
#                   <span>
#                    Twitter
#                   </span>
#                  </a>
#                 </li>
#                 <li class="share-email">
#                  <a class="fte-email-share sd-button share-icon" data-shared="" href="mailto:?subject=I thought you’d like this article from FiveThirtyEight&amp;body=https%3A%2F%2Ffivethirtyeight.com%2Ffeatures%2Fthe-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense%2F?ex_cid=538email" rel="nofollow noopener noreferrer" target="_blank" title="Click to email this to a friend">
#                   <span>
#                    Email
#                   </span>
#                  </a>
#                 </li>
#                 <li class="share-end">
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </div>
#            <!-- .share -->
#           </div>
#          </header>
#          <!-- .post-info -->
#          <figure class="single-featured-image" id="single-featured-image">
#           <span class="has-bugs post-thumbnail">
#            <div class="bug-container">
#             <picture class="featured-picture">
#              <source media="(min-width: 768px)" srcset="https://fivethirtyeight.com/wp-content/uploads/2021/04/AP21099077651088-4x3-1.jpg?w=575 1x, https://fivethirtyeight.com/wp-content/uploads/2021/04/AP21099077651088-4x3-1.jpg?w=1150 2x"/>
#              <source srcset="https://fivethirtyeight.com/wp-content/uploads/2021/04/AP21099077651088-4x3-1.jpg?w=575 1x, https://fivethirtyeight.com/wp-content/uploads/2021/04/AP21099077651088-4x3-1.jpg?w=1150 2x"/>
#              <img alt="Kristaps Porzingis,Donte DiVincenzo" class="" sizes="(max-width: 768px) 100vw, (max-width: 1080px) 66vw, 684px" src="https://fivethirtyeight.com/wp-content/uploads/2021/04/AP21099077651088-4x3-1.jpg?w=575" srcset="https://fivethirtyeight.com/wp-content/uploads/2021/04/AP21099077651088-4x3-1.jpg?w=575 1x, https://fivethirtyeight.com/wp-content/uploads/2021/04/AP21099077651088-4x3-1.jpg?w=1150 2x"/>
#             </picture>
#            </div>
#           </span>
#           <!-- .has-bugs -->
#           <figcaption class="caption featured-image-caption">
#            Kristaps Porziņģis has come alive this season for the Dallas Mavericks.
#            <p class="credits">
#             Tony Gutierrez / AP
#            </p>
#           </figcaption>
#          </figure>
#          <!-- .single-featured-image -->
#          <div class="entry-content single-post-content">
#           <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/loose.dtd">
#           <html>
#            <body>
#             <p data-paragraph="main">
#              Midway through Luka Dončić’s rookie season, the Dallas Mavericks seized on an opportunity that doesn’t come around all that often. Then-New York Knicks star Kristaps Porziņģis, still recovering from an ACL tear at the time, informed Knicks management that he wanted out of New York. Mere hours after news of the fateful meeting between Porziņģis and the front office broke, the Knicks and Mavericks
#              <a href="https://www.espn.com/nba/story/_/id/25894335/dallas-mavericks-agree-trade-new-york-knicks-kristaps-porzingis" rel="noopener" target="_blank">
#               reached a deal
#              </a>
#              to send him to Dallas.
#             </p>
#             <p data-paragraph="main">
#              Based on both the package the Mavericks sent to New York and the post-trade comments of head coach Rick Carlisle, it was clear pretty immediately that the team was thinking big. “We obviously think Porziņģis is a great young talent, similar in many ways to Dirk [Nowitzki],” Carlisle
#              <a href="https://www.espn.com/nba/story/_/id/25894335/dallas-mavericks-agree-trade-new-york-knicks-kristaps-porzingis" rel="noopener" target="_blank">
#               told ESPN Radio
#              </a>
#              . “This is kind of a Dirk-and-[Steve] Nash type of situation, only these guys are taller.”
#             </p>
#             <div class="ornamental-rule">
#              <hr/>
#              <span>
#              </span>
#             </div>
#             <h3 class="video-title">
#              What makes LeBron James so great | FiveThirtyEight
#             </h3>
#             <div class="video-placeholder videoplayer abc">
#              <iframe allow="fullscreen" class="abc-player" height="100%" scrolling="no" src="https://fivethirtyeight.abcnews.go.com/video/embed/74851925?section=sports" width="100%">
#              </iframe>
#             </div>
#             <div class="video-footer">
#              <div class="video-footer-links">
#               <a href="/videos/">
#                All Videos
#               </a>
#               <a href="https://www.youtube.com/FiveThirtyEight" target="_blank">
#                YouTube
#               </a>
#              </div>
#              <hr/>
#             </div>
#             <div class="ad-incontentteads" data-defer="none" id="ad-incontentTeads">
#             </div>
#             <p data-paragraph="main">
#              Porziņģis sat out the remainder of that season as he finished rehabbing his injured knee, but the Mavericks nonetheless
#              <a href="https://www.espn.com/nba/story/_/id/27089415/sources-mavs-reach-deals-porzingis-powell" rel="noopener" target="_blank">
#               committed to him in full
#              </a>
#              that summer. Dallas signed the sharpshooting center to a five-year, $158 million contract, locking him in as Dončić’s running mate for the long haul.
#             </p>
#             <div class="promo">
#              <p class="image">
#               <a href="https://fivethirtyeight.com/features/could-more-nba-teams-succeed-with-three-point-guards-playing-together/?cid=_inlinerelated">
#                <img alt="Three Charlotte players cut out and placed against a blue background with each other." class="pullout" data-sizes="(min-width: 440px) 153px, 100vw" data-srcset="https://fivethirtyeight.com/wp-content/uploads/2021/04/3-POINT-GUARDS-4x3-1.png?w=153&amp;quality=100&amp;strip=all 153w, https://fivethirtyeight.com/wp-content/uploads/2021/04/3-POINT-GUARDS-4x3-1.png?w=306&amp;quality=100&amp;strip=all 306w, https://fivethirtyeight.com/wp-content/uploads/2021/04/3-POINT-GUARDS-4x3-1.png?w=405&amp;quality=100&amp;strip=all 405w, https://fivethirtyeight.com/wp-content/uploads/2021/04/3-POINT-GUARDS-4x3-1.png?w=810&amp;quality=100&amp;strip=all 810w" height="115" sizes="(min-width: 440px) 153px, 100vw" srcset="https://fivethirtyeight.com/wp-content/uploads/2021/04/3-POINT-GUARDS-4x3-1.png?w=153&amp;quality=100&amp;strip=all 153w, https://fivethirtyeight.com/wp-content/uploads/2021/04/3-POINT-GUARDS-4x3-1.png?w=306&amp;quality=100&amp;strip=all 306w, https://fivethirtyeight.com/wp-content/uploads/2021/04/3-POINT-GUARDS-4x3-1.png?w=405&amp;quality=100&amp;strip=all 405w, https://fivethirtyeight.com/wp-content/uploads/2021/04/3-POINT-GUARDS-4x3-1.png?w=810&amp;quality=100&amp;strip=all 810w" width="153"/>
#               </a>
#              </p>
#              <p class="text">
#               <strong>
#                Related:
#               </strong>
#               Could More NBA Teams Succeed With Three Point Guards Playing Together?
#               <a href="https://fivethirtyeight.com/features/could-more-nba-teams-succeed-with-three-point-guards-playing-together/?cid=_inlinerelated">
#                Read more. »
#               </a>
#              </p>
#             </div>
#             <p data-paragraph="main">
#              The first season of the Dončić-Porziņģis partnership was a successful one. Dallas’s offense blitzed the NBA to the tune of a league-best 116.7 points per 100 possessions,
#              <a href="https://stathead.com/basketball/tsl_finder.cgi?request=1&amp;match=single&amp;order_by_asc=0&amp;order_by=off_rtg&amp;type=team_totals&amp;year_max=2020&amp;lg_id=NBA" rel="noopener" target="_blank">
#               breaking the all-time record
#              </a>
#              for offensive efficiency.
#              <a class="espn-footnote-link" data-footnote-content='&lt;p&gt;&lt;p&gt;Four teams are on pace to &lt;a href="https://stathead.com/basketball/tsl_finder.cgi?request=1&amp;amp;match=single&amp;amp;order_by_asc=0&amp;amp;order_by=off_rtg&amp;amp;type=team_totals&amp;amp;lg_id=NBA" target="_blank" rel="noopener"&gt;rebreak&lt;/a&gt; it this season.&lt;/p&gt;
# &lt;/p&gt;' data-footnote-id="1" href="#fn-1">
#               <sup id="ss-1">
#                1
#               </sup>
#              </a>
#              Dončić put together arguably the
#              <a href="https://fivethirtyeight.com/features/we-havent-seen-anyone-like-luka-doncic-since-lebron-james/" rel="noopener" target="_blank">
#               greatest age-20 season
#              </a>
#              in the history of the NBA, thrusting himself into the mix with the small handful of very best players in the league. The Mavs pushed the L.A. Clippers within an inch of their playoff lives but ultimately bowed out of the first round in
#              <a href="https://www.basketball-reference.com/playoffs/2020-nba-western-conference-first-round-mavericks-vs-clippers.html" rel="noopener" target="_blank">
#               six games
#              </a>
#              . Porziņģis, though, saw his own run cut three games short after
#              <a href="https://twitter.com/MavsPR/status/1299464676460429325" rel="noopener" target="_blank">
#               tearing the meniscus
#              </a>
#              in his right knee.
#             </p>
#             <p data-paragraph="main">
#              That injury kept him out of the team’s first nine games of the 2020-21 season, and he was then eased into the lineup with a lighter minutes load. The team’s roster
#              <a href="https://www.forbes.com/sites/doylerader/2021/01/10/another-dallas-mavericks-player-enters-quarantine-due-to-covid-19/?sh=d00d6ad396d6" rel="noopener" target="_blank">
#               had been decimated by COVID-19-related absences
#              </a>
#              , and Porziņģis was still rounding his way back into game shape; he struggled to get his long-range shot on line, knocking down only 28.6 percent of his deep attempts through his first nine appearances.
#             </p>
#             <p data-paragraph="main">
#              Something clicked for Porziņģis in his 10th game back, though, even as he scored just
#              <a href="https://www.basketball-reference.com/boxscores/202102010DAL.html" rel="noopener" target="_blank">
#               19 points on 6-of-15 shooting
#              </a>
#              and the Mavs lost a heartbreaker to the Suns. He scored 14 of those 19 points after halftime, and he was on the floor for the final 12 minutes and 32 seconds of the game. After playing in shorter, six-minute spurts earlier in the year, Porziņģis found the extended run refreshing.
#             </p>
#             <p data-paragraph="main">
#              “I think [playing longer stretches] gave me more time to get into a better rhythm and get better looks and not rush things — which I tend to do a lot now that I’m playing shorter minutes,” he said after the game that night,
#              <a href="https://www.dallasnews.com/sports/mavericks/2021/02/02/fully-healthy-roster-cant-save-mavericks-from-chris-pauls-clutch-wrath-in-109-108-loss-to-suns/" rel="noopener" target="_blank">
#               per the Dallas Morning News
#              </a>
#              . “That’s something maybe I can communicate [to the coaches].”
#             </p>
#             <p data-paragraph="main">
#              Two games later, Carlisle did something coaches are typically loath to do: He
#              <a href="https://fivethirtyeight.com/features/how-the-best-nba-teams-juggle-their-lineups/" rel="noopener" target="_blank">
#               rearranged his rotation
#              </a>
#              to flip the
#              <a href="https://www.pbpstats.com/wowy-combo-playing-time-distribution/nba?Season=2020-21&amp;SeasonType=Regular%2BSeason&amp;TeamId=1610612742&amp;PlayerIds=204001,1629029" rel="noopener" target="_blank">
#               rest schedules
#              </a>
#              of Porziņģis and Dončić. While Dončić had previously been the one playing nearly the entire first and third quarters, sitting at the beginning of the second and fourth and then returning for the end of each respective half, that’s now what Porziņģis does. Dončić, meanwhile, exits around the six-minute mark of the first quarter, returns a few minutes later, then takes another rest midway through the second quarter before returning to close the half. (The Mavs only sometimes give Dončić a second rest after halftime.)
#             </p>
#             <figure class="wp-block-image size-large">
#              <img alt="" class="wp-image-307735" data-src="https://fivethirtyeight.com/wp-content/uploads/2021/04/dubin-KRISTAPS-PORZINGIS.0414.png" data-srcset="https://fivethirtyeight.com/wp-content/uploads/2021/04/dubin-KRISTAPS-PORZINGIS.0414.png?w=700 1x, https://fivethirtyeight.com/wp-content/uploads/2021/04/dubin-KRISTAPS-PORZINGIS.0414.png?w=1400 2x" height="1232" loading="lazy" src="https://fivethirtyeight.com/wp-content/uploads/2021/04/dubin-KRISTAPS-PORZINGIS.0414.png" srcset="https://fivethirtyeight.com/wp-content/uploads/2021/04/dubin-KRISTAPS-PORZINGIS.0414.png?w=700 1x, https://fivethirtyeight.com/wp-content/uploads/2021/04/dubin-KRISTAPS-PORZINGIS.0414.png?w=1400 2x" width="1150"/>
#             </figure>
#             <div class="ad-incontentteads2" data-defer="none" id="ad-incontentTeads2">
#             </div>
#             <p data-paragraph="main">
#              Since Carlisle made the switch, both Porziņģis and the Mavericks have been electric. Dallas is 20-11 overall and 16-7 in games Porziņģis has played since Feb. 4, a
#              <a href="https://www.basketball-reference.com/players/p/porzikr01/gamelog/2021#255-277-sum:pgl_basic" rel="noopener" target="_blank">
#               stretch during which
#              </a>
#              he’s averaging 21.5 points, 9.8 rebounds, 1.9 assists and 1.7 blocks in 31.1 minutes per game while shooting 49.5 percent from the field and connecting on 40.7 percent of his 6.3 threes a night. Meanwhile, the Mavericks offense, which had averaged 110.9 points per 100 possessions
#              <a href="https://www.basketball-reference.com/teams/DAL/2021/gamelog-advanced/#1-22-sum:tgl_advanced" rel="noopener" target="_blank">
#               prior to the rotation switch
#              </a>
#              , has surged to 117.8 points per 100
#              <a href="https://www.basketball-reference.com/teams/DAL/2021/gamelog-advanced/#23-53-sum:tgl_advanced" rel="noopener" target="_blank">
#               across the 31 games
#              </a>
#              since then.
#             </p>
#             <p data-paragraph="main">
#              It’s the longest sustained stretch of elite-level individual offense Porziņģis has put together since the ACL injury. But there’s also been ample evidence throughout his Mavericks career that his mere presence on the floor is a net positive for the team’s offense.
#             </p>
#             <p data-paragraph="main">
#              Consider Dončić’s pick-and-roll game. Only one player (Trae Young) has been screened for more often this season than Dončić, per Second Spectrum. Among the 53 players who have run off at least 750 ball screens this year, trips that include a Dončić pick and roll have generated the ninth-most points per possession. Those pick and rolls have been more efficient when Porziņģis is the one setting the screen (1.244 points per possession) than when they’re set by anyone else (1.193).
#             </p>
#             <div class="ornamental-rule">
#              <hr/>
#              <span>
#              </span>
#             </div>
#             <h3 class="video-title">
#              Every baseball fan should know these Negro League stars | FiveThirtyEight
#             </h3>
#             <div class="video-placeholder videoplayer abc">
#              <iframe allow="fullscreen" class="abc-player" height="100%" scrolling="no" src="https://fivethirtyeight.abcnews.go.com/video/embed/76389391?section=sports" width="100%">
#              </iframe>
#             </div>
#             <div class="video-footer">
#              <div class="video-footer-links">
#               <a href="/videos/">
#                All Videos
#               </a>
#               <a href="https://www.youtube.com/FiveThirtyEight" target="_blank">
#                YouTube
#               </a>
#              </div>
#              <hr/>
#             </div>
#             <p data-paragraph="main">
#              But that’s not all that surprising. Porziņģis is 7-foot-3 and has
#              <a href="https://www.youtube.com/watch?v=T2iFAZQRk1E" rel="noopener" target="_blank">
#               from-the-logo range on his jumper
#              </a>
#              . He’s also considerably more skilled than the other players that screen for Dončić. Dončić is actually screened for by a non-Porziņģis teammate far more often than he is by Porziņģis himself, but Porziņģis’s presence on the floor has a dramatic effect on the efficiency of those plays. Dončić pick and rolls with non-Porziņģis screeners have generated 1.280 points per possession this season with Porziņģis on the floor, compared with just 1.161 with KP on the bench. The same is true on drives, where the average Dončić venture to the rim has resulted in 1.307 points with Porziņģis in the game but just 1.244 points with him on the pine.
#             </p>
#             <p data-paragraph="main">
#              What’s more, it still feels like there’s meat left on the bone for Porziņģis. His post-up numbers have crept upward in terms of both volume and efficiency this season, but he still has plenty of room to grow on that front. A player his size, with his touch, should be able to do better than the 59th percentile
#              <a class="espn-footnote-link" data-footnote-content="&lt;p&gt;&lt;p&gt;Among players with at least 100 post-ups.&lt;/p&gt;
# &lt;/p&gt;" data-footnote-id="2" href="#fn-2">
#               <sup id="ss-2">
#                2
#               </sup>
#              </a>
#              in points per possession generated when he’s thrown the ball on the block.
#             </p>
#             <div class="core-html align">
#              <section class="viz">
#               <header class="viz">
#                <h5 class="title">
#                 Porziņģis could still be scoring more on post-ups
#                </h5>
#                <p class="subtitle">
#                 Post-ups per 100 possessions and points per possession on post-ups, with scoring percentile, for Kristaps Porziņģis
#                </p>
#               </header>
#               <table class="viz full" data-carpenter-slug="dubin.porzingis.1">
#                <thead>
#                 <tr>
#                  <th class="upper" colspan="3" style="border-right: 10px solid #ffffff">
#                  </th>
#                  <th class="upper upper-text" colspan="2">
#                   Points per possession
#                  </th>
#                 </tr>
#                 <tr>
#                  <th class="no-parent text" colspan="1">
#                   Season
#                  </th>
#                  <th class="no-parent text" colspan="1">
#                   Team
#                  </th>
#                  <th class="no-parent number" colspan="1">
#                   Per 100 poss.
#                  </th>
#                  <th class="number" colspan="1" style="font-weight: 400">
#                   Average
#                  </th>
#                  <th class="number" colspan="1" style="font-weight: 400">
#                   Percentile
#                  </th>
#                 </tr>
#                </thead>
#                <tbody>
#                 <tr>
#                  <td class="text">
#                   2020-21
#                  </td>
#                  <td class="text">
#                   Dallas Mavericks
#                  </td>
#                  <td class="number">
#                   8.971
#                  </td>
#                  <td class="number">
#                   1.096
#                  </td>
#                  <td class="number">
#                   59th
#                  </td>
#                 </tr>
#                 <tr>
#                  <td class="text">
#                   2019-20
#                  </td>
#                  <td class="text">
#                   Dallas Mavericks
#                  </td>
#                  <td class="number">
#                   5.221
#                  </td>
#                  <td class="number">
#                   1.022
#                  </td>
#                  <td class="number">
#                   30th
#                  </td>
#                 </tr>
#                 <tr>
#                  <td class="text">
#                   2017-18
#                  </td>
#                  <td class="text">
#                   New York Knicks
#                  </td>
#                  <td class="number">
#                   12.605
#                  </td>
#                  <td class="number">
#                   1.058
#                  </td>
#                  <td class="number">
#                   44th
#                  </td>
#                 </tr>
#                 <tr>
#                  <td class="text">
#                   2016-17
#                  </td>
#                  <td class="text">
#                   New York Knicks
#                  </td>
#                  <td class="number">
#                   6.065
#                  </td>
#                  <td class="number">
#                   0.992
#                  </td>
#                  <td class="number">
#                   22nd
#                  </td>
#                 </tr>
#                 <tr>
#                  <td class="text">
#                   2015-16
#                  </td>
#                  <td class="text">
#                   New York Knicks
#                  </td>
#                  <td class="number">
#                   7.408
#                  </td>
#                  <td class="number">
#                   1.095
#                  </td>
#                  <td class="number">
#                   58th
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#               <footer class="viz">
#                <p class="notes">
#                 Among players with at least 100 post-ups per season. Through games of April 12, 2021.
#                </p>
#                <p class="source">
#                 Source: Second Spectrum
#                </p>
# ...
#                </a>
#               </h3>
#              </div>
#              <div class="widget-video__poster">
#               <a class="post-thumbnail" href="https://fivethirtyeight.com/videos/confidence-interval-will-andrew-yang-be-the-next-mayor-of-new-york-city/?cid=rrfeaturedvideo">
#                <button aria-label="Play" class="orange-play-button thumbnail-play-button">
#                </button>
#                <img alt="CI-YANG-standard" class="" height="225" sizes="100px" srcset="https://fivethirtyeight.com/wp-content/uploads/2021/04/CI-YANG-standard.jpg?w=300 1x, https://fivethirtyeight.com/wp-content/uploads/2021/04/CI-YANG-standard.jpg?w=600 2x" width="300">
#                </img>
#               </a>
#              </div>
#             </article>
#            </li>
#            <li>
#             <article class="widget-video" id="post-307707">
#              <div class="widget-video__content">
#               <h3 class="widget-video__title">
#                <a href="https://fivethirtyeight.com/videos/why-support-for-gun-control-hasnt-led-to-new-legislation/?cid=rrfeaturedvideo">
#                 Why Support For Gun Control Hasn’t Led To New Legislation
#                </a>
#               </h3>
#              </div>
#              <div class="widget-video__poster">
#               <a class="post-thumbnail" href="https://fivethirtyeight.com/videos/why-support-for-gun-control-hasnt-led-to-new-legislation/?cid=rrfeaturedvideo">
#                <button aria-label="Play" class="orange-play-button thumbnail-play-button">
#                </button>
#                <img alt="210412_Pod_4x3" class="" height="225" sizes="100px" srcset="https://fivethirtyeight.com/wp-content/uploads/2021/04/210412_Pod_4x3.jpg?w=300 1x, https://fivethirtyeight.com/wp-content/uploads/2021/04/210412_Pod_4x3.jpg?w=600 2x" width="300"/>
#               </a>
#              </div>
#             </article>
#            </li>
#           </ul>
#          </aside>
#          <!-- end widget -->
#         </div>
#        </div>
#        <!-- #secondary -->
#       </div>
#      </div>
#     </div>
#     <!-- .single -->
#    </div>
#    <!-- #wrapper .site-wrapper -->
#   </div>
#   <!-- .site-main -->
#   <footer class="site-footer" id="colophon">
#    <div class="site-wrapper footer-main-content">
#     <div class="footer-section-get-more">
#      Get more FiveThirtyEight
#     </div>
#     <div class="footer-section-primary-links">
#      <ul class="footer-menu">
#       <li class="footer-menu-item">
#        <a href="https://cottonbureau.com/stores/fivethirtyeight#/shop" name="&amp;lpos=fivethirtyeightFooter&amp;lid=store">
#         Store
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/newsletter/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=newsletter">
#         Newsletter
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://twitter.com/fivethirtyeight" name="&amp;lpos=fivethirtyeightFooter&amp;lid=twitter">
#         Twitter
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://www.facebook.com/fivethirtyeight" name="&amp;lpos=fivethirtyeightFooter&amp;lid=facebook">
#         Facebook
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://data.fivethirtyeight.com/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=data">
#         Data
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/features/fear-not-readers-we-have-rss-feeds/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=rss">
#         RSS
#        </a>
#       </li>
#      </ul>
#     </div>
#     <!-- .footer-primary-links -->
#     <div class="footer-section-social-follow">
#      <ul class="footer-menu">
#       <li class="footer-menu-item social-share-item">
#        <div class="fb-like" data-href="https://www.facebook.com/fivethirtyeight" data-layout="button_count">
#        </div>
#       </li>
#       <li class="footer-menu-item social-share-item">
#        <a class="twitter-follow-button" data-show-count="true" href="https://twitter.com/FiveThirtyEight">
#         Follow @FiveThirtyEight
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="footer-section-secondary-links">
#      <ul class="footer-menu">
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/contact/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=contact">
#         Contact
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/tag/fivethirtyeight-jobs/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=jobs">
#         Jobs
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/masthead/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=masthead">
#         Masthead
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://fivethirtyeight.com/how-to-pitch-fivethirtyeight/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=pitch">
#         Pitch FiveThirtyEight
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="https://disneyadsales.com/our-brands/abc-news/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=advertise">
#         Advertise With Us
#        </a>
#       </li>
#       <li class="footer-menu-item">
#        <a href="http://priv-policy.imrworldwide.com/priv/browser/us/en/optout.html" name="&amp;lpos=fivethirtyeightFooter&amp;lid=nielsen">
#         About Nielsen Measurement
#        </a>
#       </li>
#      </ul>
#     </div>
#     <!-- .footer-secondary-links -->
#     <div class="footer-section-powered-by">
#      Powered by
#      <a class="powered-by-wpcom" href="https://wpvip.com/?utm_source=vip_powered_wpcom&amp;utm_medium=web&amp;utm_campaign=VIP%20Footer%20Credit&amp;utm_term=fivethirtyeight.com" rel="generator nofollow">
#       WordPress VIP
#      </a>
#     </div>
#     <!-- .powered-by -->
#     <div class="footer-section-tertiary-links">
#      <ul class="footer-menu">
#       <li class="menu-item">
#        <a href="https://disneytermsofuse.com/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=disneyTOS" rel="noopener noreferrer" target="_blank">
#         Terms of Use
#        </a>
#       </li>
#       <li class="menu-item">
#        <a href="https://disneyprivacycenter.com/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=disneyPrivacy" rel="noopener noreferrer" target="_blank">
#         Privacy Policy
#        </a>
#       </li>
#       <li class="menu-item">
#        <a href="https://privacy.thewaltdisneycompany.com/en/dnsmi/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=doNotSell" rel="noopener noreferrer" target="_blank">
#         Do Not Sell My Info
#        </a>
#       </li>
#       <li class="menu-item">
#        <a href="https://disneyprivacycenter.com/notice-to-california-residents/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=californiaPrivacyRights" rel="noopener noreferrer" target="_blank">
#         Your California Privacy Rights
#        </a>
#       </li>
#       <li class="menu-item">
#        <a href="https://disneyprivacycenter.com/kids-privacy-policy/english/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=childrensPrivacy" rel="noopener noreferrer" target="_blank">
#         Children's Online Privacy Policy
#        </a>
#       </li>
#       <li class="menu-item">
#        <a href="https://preferences-mgr.truste.com/?type=abcnews&amp;affiliateId=11&amp;cid=clicksource_4380645_footer_interestbasedads" name="&amp;lpos=fivethirtyeightFooter&amp;lid=adPreferences" rel="noopener noreferrer" target="_blank">
#         Interest-Based Ads
#        </a>
#       </li>
#      </ul>
#      <p>
#       © 2021 ABC News Internet Ventures. All rights reserved.
#      </p>
#     </div>
#     <!-- / .footer-section-tertiary-links -->
#    </div>
#    <!-- .site-wrapper -->
#    <div class="footer-section-additional-info" id="footer-additional-info">
#     <div class="site-wrapper">
#      <button aria-label="Close" class="close-additional-info" id="close-additional-info">
#       <span class="visually-hidden">
#        Close Additional Information
#       </span>
#      </button>
#      <a href="https://disneytermsofuse.com/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=disneyTOS">
#       Terms of Use
#      </a>
#      and
#      <a href="https://disneyprivacycenter.com/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=disneyPrivacy">
#       Privacy Policy
#      </a>
#      and Safety Information/
#      <a href="https://disneyprivacycenter.com/notice-to-california-residents/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=californiaPrivacyRights">
#       Your California Privacy Rights
#      </a>
#      /
#      <a href="https://disneyprivacycenter.com/kids-privacy-policy/english/" name="&amp;lpos=fivethirtyeightFooter&amp;lid=childrensPrivacy">
#       Children's Online Privacy Policy
#      </a>
#      are applicable to you. © 2021 ABC News Internet Ventures. All rights reserved.
#      <a href="https://preferences-mgr.truste.com/?type=abcnews&amp;affiliateId=11&amp;cid=clicksource_4380645_footer_interestbasedads" name="&amp;lpos=fivethirtyeightFooter&amp;lid=adPreferences">
#       Interest-Based Ads
#      </a>
#      .
#      <a href="https://disneyprivacycenter.com/cookies-policy-translations/cookies-policy/">
#       Cookie Policy
#      </a>
#      .
#     </div>
#     <!-- .site-wrapper -->
#    </div>
#    <!-- .footer-section-additional-info -->
#   </footer>
#   <!-- .site-footer -->
#   <div id="sharing_email" style="display: none;">
#    <form action="/features/the-mavericks-bet-big-on-kristaps-porzingis-its-paying-off-on-offense-but-what-about-defense/" method="post">
#     <label for="target_email">
#      Send to Email Address
#     </label>
#     <input id="target_email" name="target_email" type="email" value="">
#      <label for="source_name">
#       Your Name
#      </label>
#      <input id="source_name" name="source_name" type="text" value="">
#       <label for="source_email">
#        Your Email Address
#       </label>
#       <input id="source_email" name="source_email" type="email" value="">
#        <input autocomplete="off" class="input" id="jetpack-source_f_name" name="source_f_name" size="25" title="This field is for validation and should not be changed" type="text" value="">
#         <img alt="loading" class="loading" height="16" src="https://fivethirtyeight.com/wp-content/mu-plugins/jetpack-9.6/modules/sharedaddy/images/loading.gif" style="float: right; display: none" width="16"/>
#         <input class="sharing_send" type="submit" value="Send Email"/>
#         <a class="sharing_cancel" href="#cancel" rel="nofollow" role="button">
#          Cancel
#         </a>
#         <div class="errors errors-1" style="display: none;">
#          Post was not sent - check your email addresses!
#         </div>
#         <div class="errors errors-2" style="display: none;">
#          Email check failed, please try again
#         </div>
#         <div class="errors errors-3" style="display: none;">
#          Sorry, your blog cannot share posts by email.
#         </div>
#        </input>
#       </input>
#      </input>
#     </input>
#    </form>
#   </div>
#   <script id="wp-util-js-extra">
#    var _wpUtilSettings = {"ajax":{"url":"\/wp-admin\/admin-ajax.php"}};
#   </script>
#   <script id="fte-main-js-extra">
#    var ESPNSocial = {"fbVersion":"6.0","fbAppId":"797620670264818"};
#   </script>
#   <script id="dtci-ads-js-extra">
#    var DTCIAdConfig = {"adSlotsToRefresh":["Banner","InContent","incontentTeads","incontentTeads2","OutStream","DailyShowHP"],"adUnitPath":"\/21783347309\/abc-news\/fivethirtyeight.com\/web\/sports","placements":{"Banner":{"out-of-page":false,"sizes":[[970,250],[970,66],[728,90],[320,50],[300,50]],"defer":"none"},"InContent":{"out-of-page":false,"sizes":[[300,250],[300,600]],"defer":"none"},"incontentTeads":{"out-of-page":false,"sizes":[1,3],"defer":"none"},"incontentTeads2":{"out-of-page":false,"sizes":[1,3],"defer":"none"},"A9InContent":{"out-of-page":false,"sizes":[[300,250],[300,600]],"defer":"none"},"OutStream":{"out-of-page":false,"sizes":[[1,3]],"defer":"none"},"DailyShowHP":{"out-of-page":false,"sizes":[[272,35]],"defer":"none"}},"slots":{"Banner":[],"InContent":[],"incontentTeads":[],"incontentTeads2":[],"A9InContent":[],"OutStream":[],"DailyShowHP":[]},"mappings":{"Banner":[[[1280,100],[[970,250],[970,66],[728,90]]],[[1024,100],[[970,250],[970,66],[728,90]]],[[768,100],[[728,90]]],[[0,0],[[320,50],[300,50]]]],"InContent":[[[0,0],[]],[[768,50],[300,250]]],"DailyShowHP":[[[0,0],[272,35]]]},"targeting":{"sp":"fivethirtyeight","objid":"307707","lang":"en","devType":"desktop","tag":["dallas-mavericks","kristaps-porzingis","luka-doncic","nba","pick-and-roll"],"hip":"0f6867372122f7136b713275935f2b3c132a831caa9286f11a414b53cdcc43ee"},"devType":"desktop","referringSite":null,"referralMap":{"facebook.com":"facebook","twitter.com":"twitter","t.co":"twitter","google.com":"google","bing.com":"bing","yahoo.com":"yahoo","www.espn.com":"espn","espn.com":"espn","instagram.com":"instagram","reddit.com":"reddit","bleacherreport.com":"bleacherreport","tumblr.com":"tumblr","t.umblr.com":"tumblr","pinterest.com":"pinterest","fivethirtyeight.com":"fivethirtyeight","grantland.com":"grantland","theundefeated.com":"theundefeated"},"useOverlay":"0","refreshSimulatenously":"1","disableInitialLoad":"1","a9id":"3899","a9Params":{"si_section":"sports","section":"story"}};
#   </script>
#   <script src="https://fivethirtyeight.com/_static/??-eJyVkEsOwjAMRC9EiFoEggXiLPm4rUt+qh1Qb08ELKIKKnU5nnke2fKZhImBIbBMLvcYSCpthMoWo+hAcZ6gjIiASY4ktYvmTnuPYT/STv7BP6lNWI+dSE7NQmfmGCp24dRLMBiXLbxjRWZG96uDB/AlBJSC6PABPODEM2A/cNWzcFZ6wGuwa8dYNiiUrT9Q1Fbi8gVu/tqcmmN7aJtzO74AX0ihKQ==" type="text/javascript">
#   </script>
#   <script id="sharing-js-js-extra">
#    var sharing_js_options = {"lang":"en","counts":"","is_stats_active":"1"};
#   </script>
#   <script id="sharing-js-js" src="https://fivethirtyeight.com/wp-content/mu-plugins/jetpack-9.6/_inc/build/sharedaddy/sharing.min.js?ver=9.6.1">
#   </script>
#   <script id="sharing-js-js-after">
#    var windowOpen;
# 			( function () {
# 				function matches( el, sel ) {
# 					return !! (
# 						el.matches && el.matches( sel ) ||
# 						el.msMatchesSelector && el.msMatchesSelector( sel )
# 					);
# 				}
#
# 				document.body.addEventListener( 'click', function ( event ) {
# 					if ( ! event.target ) {
# 						return;
# 					}
#
# 					var el;
# 					if ( matches( event.target, 'a.share-facebook' ) ) {
# 						el = event.target;
# 					} else if ( event.target.parentNode && matches( event.target.parentNode, 'a.share-facebook' ) ) {
# 						el = event.target.parentNode;
# 					}
#
# 					if ( el ) {
# 						event.preventDefault();
#
# 						// If there's another sharing window open, close it.
# 						if ( typeof windowOpen !== 'undefined' ) {
# 							windowOpen.close();
# 						}
# 						windowOpen = window.open( el.getAttribute( 'href' ), 'wpcomfacebook', 'menubar=1,resizable=1,width=600,height=400' );
# 						return false;
# 					}
# 				} );
# 			} )();
# var windowOpen;
# 			( function () {
# 				function matches( el, sel ) {
# 					return !! (
# 						el.matches && el.matches( sel ) ||
# 						el.msMatchesSelector && el.msMatchesSelector( sel )
# 					);
# 				}
#
# 				document.body.addEventListener( 'click', function ( event ) {
# 					if ( ! event.target ) {
# 						return;
# 					}
#
# 					var el;
# 					if ( matches( event.target, 'a.share-twitter' ) ) {
# 						el = event.target;
# 					} else if ( event.target.parentNode && matches( event.target.parentNode, 'a.share-twitter' ) ) {
# 						el = event.target.parentNode;
# 					}
#
# 					if ( el ) {
# 						event.preventDefault();
#
# 						// If there's another sharing window open, close it.
# 						if ( typeof windowOpen !== 'undefined' ) {
# 							windowOpen.close();
# 						}
# 						windowOpen = window.open( el.getAttribute( 'href' ), 'wpcomtwitter', 'menubar=1,resizable=1,width=600,height=350' );
# 						return false;
# 					}
# 				} );
# 			} )();
#   </script>
#   <script defer="" src="https://stats.wp.com/e-202116.js">
#   </script>
#   <script>
#    _stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:9.6.1',blog:'144970551',post:'307707',tz:'-4',srv:'fivethirtyeight.com'} ]);
# 	_stq.push([ 'clickTrackerInit', '144970551', '307707' ]);
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### Web Developer Tools
#
# We can see that going through the code might be annoying. Let's learn about the web developer tools of your web browser.
#
# #### Finding the Author
#
# In particular let's see how to find the author field!

# %%
## Our search was seeded by our look at the Web Developer Tools
soup.find('p',{'class':"single-metadata single-byline vcard"})
# Out:
# <p class="single-metadata single-byline vcard">By <a class="author url fn" href="https://fivethirtyeight.com/contributors/jared-dubin/" rel="author" title="">Jared Dubin</a></p>

# %%
## we can clean this up a little bit
soup.find('p',{'class':"single-metadata single-byline vcard"}).text.replace("By ", "")
# Out:
# 'Jared Dubin'

# %% [markdown]
# #### You Code
#
# In our final break out practice session of this notebook you'll work on getting the remaining desired data, the title and the text of the article.

# %%
## You code
## Find the title here

## Sample Solution
soup.find('h1',{'class':"article-title article-title-single entry-title"}).text.replace("\n","").replace("\t","")
# Out:
# 'The Mavericks Bet Big On Kristaps Porziņģis. It’s Paying Off On Offense, But What About Defense?'

# %%
## You code
## Find the article text here

## Sample Solution
[p.text for p in soup.find('div',{'class',"entry-content single-post-content"}).find_all("p")]
# Out:
# ['Midway through Luka Dončić’s rookie season, the Dallas Mavericks seized on an opportunity that doesn’t come around all that often. Then-New York Knicks star Kristaps Porziņģis, still recovering from an ACL tear at the time, informed Knicks management that he wanted out of New York. Mere hours after news of the fateful meeting between Porziņģis and the front office broke, the Knicks and Mavericks reached a deal to send him to Dallas.',
#  'Based on both the package the Mavericks sent to New York and the post-trade comments of head coach Rick Carlisle, it was clear pretty immediately that the team was thinking big. “We obviously think Porziņģis is a great young talent, similar in many ways to Dirk [Nowitzki],” Carlisle told ESPN Radio. “This is kind of a Dirk-and-[Steve] Nash type of situation, only these guys are taller.”',
#  'Porziņģis sat out the remainder of that season as he finished rehabbing his injured knee, but the Mavericks nonetheless committed to him in full that summer. Dallas signed the sharpshooting center to a five-year, $158 million contract, locking him in as Dončić’s running mate for the long haul.',
#  '\n\n',
#  '\nRelated:\n\t\t\t\tCould More NBA Teams Succeed With Three Point Guards Playing Together? Read more. »\n',
#  'The first season of the Dončić-Porziņģis partnership was a successful one. Dallas’s offense blitzed the NBA to the tune of a league-best 116.7 points per 100 possessions, breaking the all-time record for offensive efficiency.1 Dončić put together arguably the greatest age-20 season in the history of the NBA, thrusting himself into the mix with the small handful of very best players in the league. The Mavs pushed the L.A. Clippers within an inch of their playoff lives but ultimately bowed out of the first round in six games. Porziņģis, though, saw his own run cut three games short after tearing the meniscus in his right knee.',
#  'That injury kept him out of the team’s first nine games of the 2020-21 season, and he was then eased into the lineup with a lighter minutes load. The team’s roster had been decimated by COVID-19-related absences, and Porziņģis was still rounding his way back into game shape; he struggled to get his long-range shot on line, knocking down only 28.6 percent of his deep attempts through his first nine appearances.',
#  'Something clicked for Porziņģis in his 10th game back, though, even as he scored just 19 points on 6-of-15 shooting and the Mavs lost a heartbreaker to the Suns. He scored 14 of those 19 points after halftime, and he was on the floor for the final 12 minutes and 32 seconds of the game. After playing in shorter, six-minute spurts earlier in the year, Porziņģis found the extended run refreshing.',
#  '“I think [playing longer stretches] gave me more time to get into a better rhythm and get better looks and not rush things — which I tend to do a lot now that I’m playing shorter minutes,” he said after the game that night, per the Dallas Morning News. “That’s something maybe I can communicate [to the coaches].”',
#  'Two games later, Carlisle did something coaches are typically loath to do: He rearranged his rotation to flip the rest schedules of Porziņģis and Dončić. While Dončić had previously been the one playing nearly the entire first and third quarters, sitting at the beginning of the second and fourth and then returning for the end of each respective half, that’s now what Porziņģis does. Dončić, meanwhile, exits around the six-minute mark of the first quarter, returns a few minutes later, then takes another rest midway through the second quarter before returning to close the half. (The Mavs only sometimes give Dončić a second rest after halftime.)',
#  'Since Carlisle made the switch, both Porziņģis and the Mavericks have been electric. Dallas is 20-11 overall and 16-7 in games Porziņģis has played since Feb. 4, a stretch during which he’s averaging 21.5 points, 9.8 rebounds, 1.9 assists and 1.7 blocks in 31.1 minutes per game while shooting 49.5 percent from the field and connecting on 40.7 percent of his 6.3 threes a night. Meanwhile, the Mavericks offense, which had averaged 110.9 points per 100 possessions prior to the rotation switch, has surged to 117.8 points per 100 across the 31 games since then.',
#  'It’s the longest sustained stretch of elite-level individual offense Porziņģis has put together since the ACL injury. But there’s also been ample evidence throughout his Mavericks career that his mere presence on the floor is a net positive for the team’s offense.',
#  'Consider Dončić’s pick-and-roll game. Only one player (Trae Young) has been screened for more often this season than Dončić, per Second Spectrum. Among the 53 players who have run off at least 750 ball screens this year, trips that include a Dončić pick and roll have generated the ninth-most points per possession. Those pick and rolls have been more efficient when Porziņģis is the one setting the screen (1.244 points per possession) than when they’re set by anyone else (1.193).',
#  'But that’s not all that surprising. Porziņģis is 7-foot-3 and has from-the-logo range on his jumper. He’s also considerably more skilled than the other players that screen for Dončić. Dončić is actually screened for by a non-Porziņģis teammate far more often than he is by Porziņģis himself, but Porziņģis’s presence on the floor has a dramatic effect on the efficiency of those plays. Dončić pick and rolls with non-Porziņģis screeners have generated 1.280 points per possession this season with Porziņģis on the floor, compared with just 1.161 with KP on the bench. The same is true on drives, where the average Dončić venture to the rim has resulted in 1.307 points with Porziņģis in the game but just 1.244 points with him on the pine. ',
#  'What’s more, it still feels like there’s meat left on the bone for Porziņģis. His post-up numbers have crept upward in terms of both volume and efficiency this season, but he still has plenty of room to grow on that front. A player his size, with his touch, should be able to do better than the 59th percentile2 in points per possession generated when he’s thrown the ball on the block.',
#  'Post-ups per 100 possessions and points per possession on post-ups, with scoring percentile, for Kristaps Porziņģis',
#  'Among players with at least 100 post-ups per season. Through games of April 12, 2021.',
#  'Source: Second Spectrum',
#  'At the moment, Porziņģis also has a microscopic free-throw rate. It’s sitting at a career-low 0.194 free throws per field-goal attempt, according to Basketball-Reference.com, a figure so low that it actually ranks 744th out of the 813 player-seasons among 7-footers who played at least 1,000 minutes in a given year. Considering he’s an 80.6 percent free-throw shooter for his career, getting to the line more often would surely make him an even more efficient scorer. (It would also do more to justify his constant agitation for more touches.)',
#  'Still, it seems fairly clear at this point that when Porziņģis is healthy, he and Dončić will combine to make the Mavericks a devastatingly efficient offensive team. We have nearly two seasons’ worth of evidence for that, and each player’s skill set lends itself to keeping that going for quite a while.',
#  '\n\n',
#  '\nRelated:\n\t\t\t\tThe Best NBA Players, According To RAPTOR Read more. »\n',
#  'The questions come on the other end of the floor, where Porziņģis, due to both his size and the outsized burden Dončić carries on offense, has been and will continue to be tasked with the larger load. And it remains to be seen whether he’ll be up to the task.',
#  'Porziņģis has always had good rim-protection numbers, going back to his early days as a Knick. But it’s not yet clear that his prowess in that area definitively dissuades opponents from venturing into the paint. According to Second Spectrum, Maverick opponents have taken a slightly greater share of their shots from inside the lane (and a smaller share from the midrange area) with Porziņģis on the floor this season than when he’s been off it.',
#  'Share of shots by location on the floor for Maverick opponents with Kristaps Porziņģis on and off the court, 2020-21 season',
#  'Through games of April 12.',
#  'Source: Second Spectrum',
#  'The league’s best paint-patrollers don’t just thwart opponent attempts at the basket but also prevent them from happening in the first place. If Porziņģis’s help-defense instincts kicked in a bit sooner or if he were a bit quicker to rotate over from the weak side when he sees a driver blow past a teammate on the perimeter, he would be a more effective deterrent. Instead, his help defense is below-average, despite his penchant for blocking shots.',
#  'Porziņģis also has occasional difficulties defending in space, though he has been somewhat better in that area in recent weeks. Smart teams still configure their offense to force him to change directions multiple times in quick succession (something that 7-foot-3 people unsurprisingly struggle to do) or else keep up with smaller, speedier guards as they turn the corner, particularly on pick and rolls. There are 70 players who have defended the screener on 500 or more ball-screens this season, per Second Spectrum, and the 1.129 points per possession teams have scored when Porziņģis is that defender is 23rd-highest.',
#  'The Mavericks do their best to keep him at center (he’s played 99 percent of his regular-season minutes in Dallas at the five, compared with just 22 percent in New York) and thus close to the rim, where his height and monstrous limbs play up. They also try to pair him with mobile frontcourt partners like Maxi Kleber, so he doesn’t have to jump out on the perimeter all that often. But opponents can still force it, and when they do, it’s a problem. Rest assured, they will do this in the postseason, and they will do it relentlessly until Porziņģis figures out how to stop it.',
#  'Pre-injury, Porziņģis earned the nickname “Unicorn” specifically because he looked like the rare player capable of creating gobs of space on one end and just as easily erasing them on the other. Dirk on offense, and something like Draymond-Green-plus-9-inches on defense.\xa0',
#  'Porziņģis can still do the former because of his size and range, and it’s hugely valuable both individually and on a team level. His ability to do the latter is more limited, though, as is the area of the floor he can effectively erase. That alters the ceiling for both him as a player and the Mavericks as a team, and makes building around him and Dončić a trickier proposition.',
#  'Check out our latest NBA predictions.']

# %% [markdown]
# ## Going Beyond BeautifulSoup, APIs
#
# As we've seen above `BeautifulSoup` can be quite powerful, but also a hassle to code. Sometimes there are websites or apps that are so popular that people have taken the time to write API python wrappers.
#
# In layman's terms an API is a way for you to "talk" to the website and tell it what data you want to get back. For a better explanation watch this short YouTube video on your own time, <a href="https://www.youtube.com/watch?v=s7wmiS2mSXY">https://www.youtube.com/watch?v=s7wmiS2mSXY</a>. A python wrapper for an API is just a python package that was written so you can communicate with the API in python as opposed to some other programming language.
#
# Some popular python wrappers include:
# - <a href="https://www.tweepy.org/">Tweepy</a>
# - <a href="https://spotipy.readthedocs.io/en/2.15.0/">Spotipy</a>
# - <a href="https://praw.readthedocs.io/en/latest/">praw</a>
# - <a href="https://github.com/realpython/list-of-python-api-wrappers">And more!</a>
#
# Many APIs require you to have developer credentials (for example the Twitter API), so if you have a project idea that may utilize an API you'll want to apply for the credentials ASAP. Some can take a long time to grant you access.

# %% [markdown]
# ## That's It!
#
# That's it for this notebook. For additional practice check out the corresponding homework notebook that has problems practicing what we learned in this notebook and problems expanding upon this notebook for more advanced scraping.
#
# See you in the next notebook where we briefly discuss how to use python to access a database.

# %% [markdown]
# This notebook was written for the Erd&#337;s Institute C&#337;de Data Science Boot Camp by Matthew Osborne, Ph. D., 2021.
#
# Redistribution of the material contained in this repository is conditional on acknowledgement of Matthew Tyler Osborne, Ph.D.'s original authorship and sponsorship of the Erdős Institute as subject to the license (see License.md)
